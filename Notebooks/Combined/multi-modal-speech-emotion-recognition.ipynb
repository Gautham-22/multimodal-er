# %%
# !pip install transformers
# !pip install tensorboardx
# !pip install chardet
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.33.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: tensorboardx in /opt/conda/lib/python3.10/site-packages (2.6)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardx) (1.23.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardx) (21.3)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /opt/conda/lib/python3.10/site-packages (from tensorboardx) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardx) (3.0.9)
# Collecting chardet
#   Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 4.0 MB/s eta 0:00:0000:01
# Installing collected packages: chardet
# Successfully installed chardet-5.2.0

# %% [markdown]
# # Necessary imports

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.backend_bases import RendererBase
from scipy import signal
from scipy.io import wavfile
import os
from PIL import Image
from scipy.fftpack import fft
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils import data
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from tensorboardX import SummaryWriter
import csv
# from file_util import *
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # File util

# %%
#-*- coding: utf-8 -*-


import os
import chardet

'''
dirname        : path that need to be searched
ret                : files in the dirname (recursive)
list_avoid_dir : dirname need to be skipped
usage           : 
    list_files = []
    file_search(dirname, list_files):   
'''
def file_search(dirname, ret, list_avoid_dir=[]):
    
    filenames = os.listdir(dirname)
    
    for filename in filenames:
        full_filename = os.path.join(dirname, filename)

        if os.path.isdir(full_filename) :
            if full_filename.split('/')[-1] in list_avoid_dir:
                continue
            else:
                file_search(full_filename, ret, list_avoid_dir)
            
        else:
            ret.append( full_filename )          

            

'''
filename : filename (inc. path) that will be inspected
'''
def find_encoding(filename):
    rawdata = open(filename, 'rb').read()
    result = chardet.detect(rawdata)
    charenc = result['encoding']    
    return charenc
            
'''
dir_name : dir_name (inc. path) that will be created ( full-path name )
'''
def create_folder(dir_name):
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)

# %%
list_files = []
for x in range(5):
    sess_name = 'Session' + str(x+1)
    path = '/kaggle/input/iemocapfullrelease/IEMOCAP_full_release/'+ sess_name + '/sentences/wav/'
    file_search(path, list_files)
    list_files = sorted(list_files)
    print (sess_name + ", #sum files: " + str(len(list_files)))
#extract_feature( list_files, out_file )
# Out:
# Session1, #sum files: 1820
# Session2, #sum files: 3633
# Session3, #sum files: 5769
# Session4, #sum files: 7873
# Session5, #sum files: 10043

# %% [markdown]
# # Attention Based Fully Convolutional Network for Speech Emotion Recognition

# %%
def audio2spectrogram(filepath):
    #fig = plt.figure(figsize=(5,5))
    samplerate, test_sound  = wavfile.read(filepath,mmap=True)
    #print('samplerate',samplerate)
    _, spectrogram = log_specgram(test_sound, samplerate)
    #print(spectrogram.shape)
    #print(type(spectrogram))
    #plt.imshow(spectrogram.T, aspect='auto', origin='lower')
    return spectrogram
    
def audio2wave(filepath):
    fig = plt.figure(figsize=(5,5))
    samplerate, test_sound  = wavfile.read(filepath,mmap=True)
    plt.plot(test_sound)
    

def log_specgram(audio, sample_rate, window_size=40,
                 step_size=20, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    #print('noverlap',noverlap)
    #print('nperseg',nperseg)
    freqs, _, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, np.log(spec.T.astype(np.float32) + eps)

N_CHANNELS = 3
def get_3d_spec(Sxx_in, moments=None):
    if moments is not None:
        (base_mean, base_std, delta_mean, delta_std,
             delta2_mean, delta2_std) = moments
    else:
        base_mean, delta_mean, delta2_mean = (0, 0, 0)
        base_std, delta_std, delta2_std = (1, 1, 1)
    h, w = Sxx_in.shape
    right1 = np.concatenate([Sxx_in[:, 0].reshape((h, -1)), Sxx_in], axis=1)[:, :-1]
    delta = (Sxx_in - right1)[:, 1:]
    delta_pad = delta[:, 0].reshape((h, -1))
    delta = np.concatenate([delta_pad, delta], axis=1)
    right2 = np.concatenate([delta[:, 0].reshape((h, -1)), delta], axis=1)[:, :-1]
    delta2 = (delta - right2)[:, 1:]
    delta2_pad = delta2[:, 0].reshape((h, -1))
    delta2 = np.concatenate([delta2_pad, delta2], axis=1)
    base = (Sxx_in - base_mean) / base_std
    delta = (delta - delta_mean) / delta_std
    delta2 = (delta2 - delta2_mean) / delta2_std
    stacked = [arr.reshape((h, w, 1)) for arr in (base, delta, delta2)]
    return np.concatenate(stacked, axis=2)

# %%
import pandas as pd
df=pd.read_csv('/kaggle/input/emotion-recognition/processed_data.csv')

# %%
df['label'] = pd.to_numeric(df['label'])

# %% [markdown]
# # *EXTACT THE MFCC FEATURE USING LIBROSA*

# %%
no_rows=len(list_files)
index=0
sprectrogram_shape=[]
docs = []
bookmark=0
extraLabel=0
for everyFile in list_files:
  if(everyFile.split('/')[-1].endswith('.wav')):
    filename=everyFile.split('/')[-1].strip('.wav')
    lable=df.loc[df['sessionID']==filename]['label'].values[0]
    text=df.loc[df['sessionID']==filename]['text'].values[0]
    print('label',lable)
    if(lable!=-1):
      #sprectrogram_shape.append(audio2spectrogram(everyFile))
      spector=audio2spectrogram(everyFile)
      spector=get_3d_spec(spector)
      npimg = np.transpose(spector,(2,0,1))
      input_tensor=torch.tensor(npimg)
      input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model
      #X, sample_rate = librosa.load(everyFile, res_type='kaiser_fast',sr=22050*2)
      #sample_rate = np.array(sample_rate)
      #mfccs = np.mean(librosa.feature.mfcc(y=X,sr=sample_rate,n_mfcc=13),axis=0)
      #feature = mfccs
      docs.append({
         'fileName':everyFile.split('/')[-1].strip('.wav'),
         'text':text,
         'sprectrome':input_batch,
         'label':lable
              })
      index+=1
      print('index',index)
    else:
      extraLabel=extraLabel+1
      print('extraLabel',extraLabel)
# Out:
# label 3
# index 1
# label 3
# index 2
# label 3
# index 3
# label -1
# extraLabel 1
# label -1
# extraLabel 2
# label 3
# index 4
# label -1
# extraLabel 3
# label -1
# extraLabel 4
# label -1
# extraLabel 5
# label -1
# extraLabel 6
# label -1
# extraLabel 7
# label -1
# extraLabel 8
# label 0
# index 5
# label -1
# extraLabel 9
# label 3
# index 6
# label -1
# extraLabel 10
# label -1
# extraLabel 11
# label -1
# extraLabel 12
# label -1
# extraLabel 13
# label -1
# extraLabel 14
# label -1
# extraLabel 15
# label -1
# extraLabel 16
# label -1
# extraLabel 17
# label -1
# extraLabel 18
# label -1
# extraLabel 19
# label -1
# extraLabel 20
# label -1
# extraLabel 21
# label 0
# index 7
# label -1
# extraLabel 22
# label 0
# index 8
# label 2
# index 9
# label 2
# index 10
# label 2
# index 11
# label 3
# index 12
# label 2
# index 13
# label 2
# index 14
# label 3
# index 15
# label -1
# extraLabel 23
# label 2
# index 16
# label -1
# extraLabel 24
# label 2
# index 17
# label -1
# extraLabel 25
# label 2
# index 18
# label 2
# index 19
# label 2
# index 20
# label 2
# index 21
# label 3
# index 22
# label 2
# index 23
# label 3
# index 24
# label 2
# index 25
# label 2
# index 26
# label -1
# extraLabel 26
# label 2
# index 27
# label -1
# extraLabel 27
# label -1
# extraLabel 28
# label -1
# extraLabel 29
# label 2
# index 28
# label -1
# extraLabel 30
# label -1
# extraLabel 31
# label -1
# extraLabel 32
# label 2
# index 29
# label 2
# index 30
# label 2
# index 31
# label 3
# index 32
# label 2
# index 33
# label 2
# index 34
# label 3
# index 35
# label -1
# extraLabel 33
# label 1
# index 36
# label 1
# index 37
# label 1
# index 38
# label -1
# extraLabel 34
# label 1
# index 39
# label 1
# index 40
# label 1
# index 41
# label -1
# extraLabel 35
# label 1
# index 42
# label 1
# index 43
# label 1
# index 44
# label -1
# extraLabel 36
# label 1
# index 45
# label 1
# index 46
# label -1
# extraLabel 37
# label 1
# index 47
# label 1
# index 48
# label 3
# index 49
# label 3
# index 50
# label 3
# index 51
# label -1
# extraLabel 38
# label 1
# index 52
# label 3
# index 53
# label 3
# index 54
# label 1
# index 55
# label 1
# index 56
# label 1
# index 57
# label 3
# index 58
# label 3
# index 59
# label -1
# extraLabel 39
# label 1
# index 60
# label -1
# extraLabel 40
# label -1
# extraLabel 41
# label 3
# index 61
# label 1
# index 62
# label 3
# index 63
# label 3
# index 64
# label -1
# extraLabel 42
# label 3
# index 65
# label -1
# extraLabel 43
# label 1
# index 66
# label 1
# index 67
# label 1
# index 68
# label 3
# index 69
# label -1
# extraLabel 44
# label -1
# extraLabel 45
# label 3
# index 70
# label 3
# index 71
# label 3
# index 72
# label 1
# index 73
# label 1
# index 74
# label 3
# index 75
# label 3
# index 76
# label 3
# index 77
# label -1
# extraLabel 46
# label -1
# extraLabel 47
# label -1
# extraLabel 48
# label 3
# index 78
# label 3
# index 79
# label -1
# extraLabel 49
# label -1
# extraLabel 50
# label 3
# index 80
# label -1
# extraLabel 51
# label -1
# extraLabel 52
# label -1
# extraLabel 53
# label 3
# index 81
# label 3
# index 82
# label -1
# extraLabel 54
# label -1
# extraLabel 55
# label -1
# extraLabel 56
# label -1
# extraLabel 57
# label -1
# extraLabel 58
# label -1
# extraLabel 59
# label -1
# extraLabel 60
# label -1
# extraLabel 61
# label -1
# extraLabel 62
# label -1
# extraLabel 63
# label -1
# extraLabel 64
# label -1
# extraLabel 65
# label -1
# extraLabel 66
# label 0
# index 83
# label 0
# index 84
# label 0
# index 85
# label 0
# index 86
# label 0
# index 87
# label 0
# index 88
# label 3
# index 89
# label 3
# index 90
# label 3
# index 91
# label 3
# index 92
# label 3
# index 93
# label 3
# index 94
# label 3
# index 95
# label 3
# index 96
# label 3
# index 97
# label 3
# index 98
# label 3
# index 99
# label 3
# index 100
# label 3
# index 101
# label 3
# index 102
# label 3
# index 103
# label 3
# index 104
# label 3
# index 105
# label 3
# index 106
# label 3
# index 107
# label 3
# index 108
# label 3
# index 109
# label 3
# index 110
# label 3
# index 111
# label 3
# index 112
# label 3
# index 113
# label 3
# index 114
# label 3
# index 115
# label 3
# index 116
# label 3
# index 117
# label -1
# extraLabel 67
# label -1
# extraLabel 68
# label 3
# index 118
# label 3
# index 119
# label -1
# extraLabel 69
# label -1
# extraLabel 70
# label -1
# extraLabel 71
# label -1
# extraLabel 72
# label -1
# extraLabel 73
# label -1
# extraLabel 74
# label -1
# extraLabel 75
# label -1
# extraLabel 76
# label -1
# extraLabel 77
# label -1
# extraLabel 78
# label -1
# extraLabel 79
# label -1
# extraLabel 80
# label 0
# index 120
# label 0
# index 121
# label -1
# extraLabel 81
# label 0
# index 122
# label 0
# index 123
# label -1
# extraLabel 82
# label 0
# index 124
# label 0
# index 125
# label 0
# index 126
# label 0
# index 127
# label 0
# index 128
# label 0
# index 129
# label 0
# index 130
# label 0
# index 131
# label 0
# index 132
# label 0
# index 133
# label 0
# index 134
# label 0
# index 135
# label 0
# index 136
# label -1
# extraLabel 83
# label 0
# index 137
# label 0
# index 138
# label 0
# index 139
# label 3
# index 140
# label 1
# index 141
# label 1
# index 142
# label 3
# index 143
# label 3
# index 144
# label 3
# index 145
# label 3
# index 146
# label 3
# index 147
# label 3
# index 148
# label 3
# index 149
# label 3
# index 150
# label 3
# index 151
# label 3
# index 152
# label 3
# index 153
# label 3
# index 154
# label 3
# index 155
# label 3
# index 156
# label 3
# index 157
# label -1
# extraLabel 84
# label 3
# index 158
# label 3
# index 159
# label -1
# extraLabel 85
# label 3
# index 160
# label 3
# index 161
# label 3
# index 162
# label 3
# index 163
# label 3
# index 164
# label 3
# index 165
# label 3
# index 166
# label 3
# index 167
# label 3
# index 168
# label 3
# index 169
# label -1
# extraLabel 86
# label -1
# extraLabel 87
# label 3
# index 170
# label 3
# index 171
# label -1
# extraLabel 88
# label -1
# extraLabel 89
# label 2
# index 172
# label 3
# index 173
# label 3
# index 174
# label 2
# index 175
# label 2
# index 176
# label 2
# index 177
# label 2
# index 178
# label 3
# index 179
# label 2
# index 180
# label 2
# index 181
# label 2
# index 182
# label 2
# index 183
# label 2
# index 184
# label 2
# index 185
# label 3
# index 186
# label -1
# extraLabel 90
# label 3
# index 187
# label 3
# index 188
# label 2
# index 189
# label 2
# index 190
# label 2
# index 191
# label 2
# index 192
# label 2
# index 193
# label 2
# index 194
# label 2
# index 195
# label 3
# index 196
# label 2
# index 197
# label 2
# index 198
# label 3
# index 199
# label 3
# index 200
# label 2
# index 201
# label 3
# index 202
# label 3
# index 203
# label 3
# index 204
# label 2
# index 205
# label 3
# index 206
# label 3
# index 207
# label 3
# index 208
# label 3
# index 209
# label 3
# index 210
# label 3
# index 211
# label 3
# index 212
# label 3
# index 213
# label 3
# index 214
# label -1
# extraLabel 91
# label 1
# index 215
# label -1
# extraLabel 92
# label 1
# index 216
# label 1
# index 217
# label 1
# index 218
# label 1
# index 219
# label -1
# extraLabel 93
# label -1
# extraLabel 94
# label -1
# extraLabel 95
# label 1
# index 220
# label 1
# index 221
# label -1
# extraLabel 96
# label 1
# index 222
# label 1
# index 223
# label -1
# extraLabel 97
# label -1
# extraLabel 98
# label 1
# index 224
# label 1
# index 225
# label 1
# index 226
# label 1
# index 227
# label 1
# index 228
# label 1
# index 229
# label 1
# index 230
# label 1
# index 231
# label 1
# index 232
# label 1
# index 233
# label 1
# index 234
# label -1
# extraLabel 99
# label -1
# extraLabel 100
# label 3
# index 235
# label 3
# index 236
# label 1
# index 237
# label 1
# index 238
# label -1
# extraLabel 101
# label 1
# index 239
# label 3
# index 240
# label 1
# index 241
# label -1
# extraLabel 102
# label -1
# extraLabel 103
# label -1
# extraLabel 104
# label -1
# extraLabel 105
# label -1
# extraLabel 106
# label 3
# index 242
# label -1
# extraLabel 107
# label -1
# extraLabel 108
# label -1
# extraLabel 109
# label -1
# extraLabel 110
# label -1
# extraLabel 111
# label -1
# extraLabel 112
# label -1
# extraLabel 113
# label -1
# extraLabel 114
# label -1
# extraLabel 115
# label 3
# index 243
# label -1
# extraLabel 116
# label -1
# extraLabel 117
# label -1
# extraLabel 118
# label -1
# extraLabel 119
# label -1
# extraLabel 120
# label -1
# extraLabel 121
# label -1
# extraLabel 122
# label -1
# extraLabel 123
# label -1
# extraLabel 124
# label -1
# extraLabel 125
# label -1
# extraLabel 126
# label -1
# extraLabel 127
# label -1
# extraLabel 128
# label -1
# extraLabel 129
# label -1
# extraLabel 130
# label -1
# extraLabel 131
# label -1
# extraLabel 132
# label -1
# extraLabel 133
# label 3
# index 244
# label 0
# index 245
# label -1
# extraLabel 134
# label 0
# index 246
# label 0
# index 247
# label -1
# extraLabel 135
# label -1
# extraLabel 136
# label 0
# index 248
# label 0
# index 249
# label -1
# extraLabel 137
# label -1
# extraLabel 138
# label 3
# index 250
# label 3
# index 251
# label 3
# index 252
# label 3
# index 253
# label 3
# index 254
# label -1
# extraLabel 139
# label -1
# extraLabel 140
# label 3
# index 255
# label -1
# extraLabel 141
# label -1
# extraLabel 142
# label 3
# index 256
# label -1
# extraLabel 143
# label 3
# index 257
# label -1
# extraLabel 144
# label 3
# index 258
# label 3
# index 259
# label 3
# index 260
# label 3
# index 261
# label -1
# extraLabel 145
# label 0
# index 262
# label -1
# extraLabel 146
# label -1
# extraLabel 147
# label -1
# extraLabel 148
# label 3
# index 263
# label 3
# index 264
# label 3
# index 265
# label -1
# extraLabel 149
# label -1
# extraLabel 150
# label -1
# extraLabel 151
# label -1
# extraLabel 152
# label -1
# extraLabel 153
# label -1
# extraLabel 154
# label -1
# extraLabel 155
# label -1
# extraLabel 156
# label 3
# index 266
# label -1
# extraLabel 157
# label -1
# extraLabel 158
# label -1
# extraLabel 159
# label -1
# extraLabel 160
# label 3
# index 267
# label 3
# index 268
# label -1
# extraLabel 161
# label -1
# extraLabel 162
# label -1
# extraLabel 163
# label -1
# extraLabel 164
# label -1
# extraLabel 165
# label -1
# extraLabel 166
# label 0
# index 269
# label 0
# index 270
# label 0
# index 271
# label 0
# index 272
# label 0
# index 273
# label 0
# index 274
# label 0
# index 275
# label 0
# index 276
# label 0
# index 277
# label 0
# index 278
# label 0
# index 279
# label -1
# extraLabel 167
# label -1
# extraLabel 168
# label 3
# index 280
# label -1
# extraLabel 169
# label -1
# extraLabel 170
# label 3
# index 281
# label -1
# extraLabel 171
# label -1
# extraLabel 172
# label -1
# extraLabel 173
# label 3
# index 282
# label -1
# extraLabel 174
# label -1
# extraLabel 175
# label -1
# extraLabel 176
# label -1
# extraLabel 177
# label -1
# extraLabel 178
# label -1
# extraLabel 179
# label -1
# extraLabel 180
# label -1
# extraLabel 181
# label 0
# index 283
# label 3
# index 284
# label 3
# index 285
# label 3
# index 286
# label 3
# index 287
# label 3
# index 288
# label 3
# index 289
# label 3
# index 290
# label 3
# index 291
# label 3
# index 292
# label 3
# index 293
# label 1
# index 294
# label 1
# index 295
# label 1
# index 296
# label 1
# index 297
# label 3
# index 298
# label 3
# index 299
# label 3
# index 300
# label 1
# index 301
# label -1
# extraLabel 182
# label 1
# index 302
# label 1
# index 303
# label 1
# index 304
# label 3
# index 305
# label -1
# extraLabel 183
# label -1
# extraLabel 184
# label -1
# extraLabel 185
# label -1
# extraLabel 186
# label -1
# extraLabel 187
# label 3
# index 306
# label 3
# index 307
# label 2
# index 308
# label 3
# index 309
# label -1
# extraLabel 188
# label -1
# extraLabel 189
# label -1
# extraLabel 190
# label 1
# index 310
# label 3
# index 311
# label 3
# index 312
# label -1
# extraLabel 191
# label 3
# index 313
# label 3
# index 314
# label 3
# index 315
# label -1
# extraLabel 192
# label -1
# extraLabel 193
# label 1
# index 316
# label 1
# index 317
# label 1
# index 318
# label -1
# extraLabel 194
# label -1
# extraLabel 195
# label -1
# extraLabel 196
# label -1
# extraLabel 197
# label 1
# index 319
# label 1
# index 320
# label 1
# index 321
# label -1
# extraLabel 198
# label 1
# index 322
# label 1
# index 323
# label 2
# index 324
# label 2
# index 325
# label 2
# index 326
# label 2
# index 327
# label 2
# index 328
# label 2
# index 329
# label 2
# index 330
# label 2
# index 331
# label 2
# index 332
# label 2
# index 333
# label -1
# extraLabel 199
# label 2
# index 334
# label 2
# index 335
# label -1
# extraLabel 200
# label -1
# extraLabel 201
# label 2
# index 336
# label 3
# index 337
# label -1
# extraLabel 202
# label 3
# index 338
# label -1
# extraLabel 203
# label -1
# extraLabel 204
# label -1
# extraLabel 205
# label 3
# index 339
# label -1
# extraLabel 206
# label 0
# index 340
# label 0
# index 341
# label 3
# index 342
# label 1
# index 343
# label 2
# index 344
# label -1
# extraLabel 207
# label -1
# extraLabel 208
# label -1
# extraLabel 209
# label -1
# extraLabel 210
# label 3
# index 345
# label -1
# extraLabel 211
# label -1
# extraLabel 212
# label -1
# extraLabel 213
# label -1
# extraLabel 214
# label -1
# extraLabel 215
# label -1
# extraLabel 216
# label -1
# extraLabel 217
# label -1
# extraLabel 218
# label 3
# index 346
# label 3
# index 347
# label -1
# extraLabel 219
# label -1
# extraLabel 220
# label 1
# index 348
# label -1
# extraLabel 221
# label -1
# extraLabel 222
# label -1
# extraLabel 223
# label -1
# extraLabel 224
# label 3
# index 349
# label 3
# index 350
# label 3
# index 351
# label 3
# index 352
# label 3
# index 353
# label -1
# extraLabel 225
# label 3
# index 354
# label 3
# index 355
# label 3
# index 356
# label 1
# index 357
# label -1
# extraLabel 226
# label -1
# extraLabel 227
# label -1
# extraLabel 228
# label 3
# index 358
# label 3
# index 359
# label -1
# extraLabel 229
# label 3
# index 360
# label 3
# index 361
# label 3
# index 362
# label 3
# index 363
# label -1
# extraLabel 230
# label -1
# extraLabel 231
# label 3
# index 364
# label -1
# extraLabel 232
# label 3
# index 365
# label 3
# index 366
# label 3
# index 367
# label 3
# index 368
# label 1
# index 369
# label 1
# index 370
# label -1
# extraLabel 233
# label 1
# index 371
# label -1
# extraLabel 234
# label 1
# index 372
# label -1
# extraLabel 235
# label -1
# extraLabel 236
# label 1
# index 373
# label 1
# index 374
# label 3
# index 375
# label 3
# index 376
# label -1
# extraLabel 237
# label -1
# extraLabel 238
# label -1
# extraLabel 239
# label -1
# extraLabel 240
# label 0
# index 377
# label -1
# extraLabel 241
# label 0
# index 378
# label 0
# index 379
# label 0
# index 380
# label -1
# extraLabel 242
# label -1
# extraLabel 243
# label -1
# extraLabel 244
# label -1
# extraLabel 245
# label 2
# index 381
# label 0
# index 382
# label 3
# index 383
# label -1
# extraLabel 246
# label 1
# index 384
# label -1
# extraLabel 247
# label -1
# extraLabel 248
# label 2
# index 385
# label 3
# index 386
# label -1
# extraLabel 249
# label -1
# extraLabel 250
# label 3
# index 387
# label -1
# extraLabel 251
# label -1
# extraLabel 252
# label -1
# extraLabel 253
# label -1
# extraLabel 254
# label -1
# extraLabel 255
# label -1
# extraLabel 256
# label -1
# extraLabel 257
# label 2
# index 388
# label 2
# index 389
# label 2
# index 390
# label -1
# extraLabel 258
# label -1
# extraLabel 259
# label -1
# extraLabel 260
# label 2
# index 391
# label 3
# index 392
# label 1
# index 393
# label 1
# index 394
# label 1
# index 395
# label 1
# index 396
# label 2
# index 397
# label 3
# index 398
# label 1
# index 399
# label 1
# index 400
# label 3
# index 401
# label -1
# extraLabel 261
# label -1
# extraLabel 262
# label -1
# extraLabel 263
# label 3
# index 402
# label -1
# extraLabel 264
# label -1
# extraLabel 265
# label -1
# extraLabel 266
# label -1
# extraLabel 267
# label -1
# extraLabel 268
# label -1
# extraLabel 269
# label -1
# extraLabel 270
# label -1
# extraLabel 271
# label -1
# extraLabel 272
# label 3
# index 403
# label 3
# index 404
# label -1
# extraLabel 273
# label 3
# index 405
# label -1
# extraLabel 274
# label 3
# index 406
# label 3
# index 407
# label 3
# index 408
# label 1
# index 409
# label -1
# extraLabel 275
# label 1
# index 410
# label -1
# extraLabel 276
# label -1
# extraLabel 277
# label -1
# extraLabel 278
# label -1
# extraLabel 279
# label -1
# extraLabel 280
# label -1
# extraLabel 281
# label 3
# index 411
# label -1
# extraLabel 282
# label -1
# extraLabel 283
# label -1
# extraLabel 284
# label 2
# index 412
# label 2
# index 413
# label -1
# extraLabel 285
# label 3
# index 414
# label -1
# extraLabel 286
# label 3
# index 415
# label 3
# index 416
# label 1
# index 417
# label -1
# extraLabel 287
# label 1
# index 418
# label 3
# index 419
# label 3
# index 420
# label 1
# index 421
# label -1
# extraLabel 288
# label -1
# extraLabel 289
# label -1
# extraLabel 290
# label -1
# extraLabel 291
# label -1
# extraLabel 292
# label 1
# index 422
# label 1
# index 423
# label 1
# index 424
# label -1
# extraLabel 293
# label -1
# extraLabel 294
# label 1
# index 425
# label 1
# index 426
# label 1
# index 427
# label -1
# extraLabel 295
# label -1
# extraLabel 296
# label -1
# extraLabel 297
# label -1
# extraLabel 298
# label -1
# extraLabel 299
# label -1
# extraLabel 300
# label -1
# extraLabel 301
# label 1
# index 428
# label 1
# index 429
# label 1
# index 430
# label -1
# extraLabel 302
# label 1
# index 431
# label -1
# extraLabel 303
# label -1
# extraLabel 304
# label -1
# extraLabel 305
# label -1
# extraLabel 306
# label 1
# index 432
# label 1
# index 433
# label -1
# extraLabel 307
# label -1
# extraLabel 308
# label -1
# extraLabel 309
# label -1
# extraLabel 310
# label -1
# extraLabel 311
# label -1
# extraLabel 312
# label 1
# index 434
# label -1
# extraLabel 313
# label 1
# index 435
# label 1
# index 436
# label 1
# index 437
# label 1
# index 438
# label -1
# extraLabel 314
# label -1
# extraLabel 315
# label 1
# index 439
# label -1
# extraLabel 316
# label -1
# extraLabel 317
# label -1
# extraLabel 318
# label -1
# extraLabel 319
# label 1
# index 440
# label -1
# extraLabel 320
# label -1
# extraLabel 321
# label 1
# index 441
# label -1
# extraLabel 322
# label -1
# extraLabel 323
# label 1
# index 442
# label 1
# index 443
# label 1
# index 444
# label -1
# extraLabel 324
# label -1
# extraLabel 325
# label -1
# extraLabel 326
# label -1
# extraLabel 327
# label -1
# extraLabel 328
# label -1
# extraLabel 329
# label -1
# extraLabel 330
# label 1
# index 445
# label -1
# extraLabel 331
# label 1
# index 446
# label 1
# index 447
# label -1
# extraLabel 332
# label 1
# index 448
# label 1
# index 449
# label 1
# index 450
# label -1
# extraLabel 333
# label 3
# index 451
# label 3
# index 452
# label -1
# extraLabel 334
# label -1
# extraLabel 335
# label -1
# extraLabel 336
# label -1
# extraLabel 337
# label -1
# extraLabel 338
# label -1
# extraLabel 339
# label -1
# extraLabel 340
# label 0
# index 453
# label 0
# index 454
# label 0
# index 455
# label 0
# index 456
# label 0
# index 457
# label 0
# index 458
# label -1
# extraLabel 341
# label -1
# extraLabel 342
# label 0
# index 459
# label 0
# index 460
# label 0
# index 461
# label 0
# index 462
# label 0
# index 463
# label 0
# index 464
# label 0
# index 465
# label 0
# index 466
# label 0
# index 467
# label 3
# index 468
# label 3
# index 469
# label 3
# index 470
# label -1
# extraLabel 343
# label 0
# index 471
# label 0
# index 472
# label 0
# index 473
# label 0
# index 474
# label 0
# index 475
# label 0
# index 476
# label 0
# index 477
# label -1
# extraLabel 344
# label 3
# index 478
# label 3
# index 479
# label -1
# extraLabel 345
# label 3
# index 480
# label -1
# extraLabel 346
# label -1
# extraLabel 347
# label 0
# index 481
# label -1
# extraLabel 348
# label -1
# extraLabel 349
# label 3
# index 482
# label 3
# index 483
# label -1
# extraLabel 350
# label -1
# extraLabel 351
# label 0
# index 484
# label -1
# extraLabel 352
# label 3
# index 485
# label -1
# extraLabel 353
# label 3
# index 486
# label 3
# index 487
# label 0
# index 488
# label 0
# index 489
# label 0
# index 490
# label 0
# index 491
# label 0
# index 492
# label 0
# index 493
# label 0
# index 494
# label 0
# index 495
# label -1
# extraLabel 354
# label 0
# index 496
# label 0
# index 497
# label 3
# index 498
# label 0
# index 499
# label 0
# index 500
# label 0
# index 501
# label 0
# index 502
# label 0
# index 503
# label 0
# index 504
# label 0
# index 505
# label 0
# index 506
# label 0
# index 507
# label 0
# index 508
# label 0
# index 509
# label -1
# extraLabel 355
# label -1
# extraLabel 356
# label -1
# extraLabel 357
# label -1
# extraLabel 358
# label -1
# extraLabel 359
# label 0
# index 510
# label 0
# index 511
# label -1
# extraLabel 360
# label -1
# extraLabel 361
# label 0
# index 512
# label 0
# index 513
# label -1
# extraLabel 362
# label -1
# extraLabel 363
# label -1
# extraLabel 364
# label -1
# extraLabel 365
# label -1
# extraLabel 366
# label -1
# extraLabel 367
# label 0
# index 514
# label 0
# index 515
# label 0
# index 516
# label 0
# index 517
# label -1
# extraLabel 368
# label 3
# index 518
# label 3
# index 519
# label -1
# extraLabel 369
# label -1
# extraLabel 370
# label -1
# extraLabel 371
# label -1
# extraLabel 372
# label -1
# extraLabel 373
# label -1
# extraLabel 374
# label -1
# extraLabel 375
# label -1
# extraLabel 376
# label 3
# index 520
# label -1
# extraLabel 377
# label -1
# extraLabel 378
# label -1
# extraLabel 379
# label -1
# extraLabel 380
# label -1
# extraLabel 381
# label -1
# extraLabel 382
# label 3
# index 521
# label -1
# extraLabel 383
# label -1
# extraLabel 384
# label -1
# extraLabel 385
# label -1
# extraLabel 386
# label -1
# extraLabel 387
# label -1
# extraLabel 388
# label -1
# extraLabel 389
# label -1
# extraLabel 390
# label -1
# extraLabel 391
# label 0
# index 522
# label -1
# extraLabel 392
# label -1
# extraLabel 393
# label -1
# extraLabel 394
# label -1
# extraLabel 395
# label 0
# index 523
# label -1
# extraLabel 396
# label -1
# extraLabel 397
# label -1
# extraLabel 398
# label -1
# extraLabel 399
# label 0
# index 524
# label 0
# index 525
# label 0
# index 526
# label -1
# extraLabel 400
# label 3
# index 527
# label -1
# extraLabel 401
# label -1
# extraLabel 402
# label -1
# extraLabel 403
# label -1
# extraLabel 404
# label -1
# extraLabel 405
# label -1
# extraLabel 406
# label -1
# extraLabel 407
# label -1
# extraLabel 408
# label 2
# index 528
# label 2
# index 529
# label -1
# extraLabel 409
# label -1
# extraLabel 410
# label 2
# index 530
# label -1
# extraLabel 411
# label 2
# index 531
# label -1
# extraLabel 412
# label 2
# index 532
# label -1
# extraLabel 413
# label 2
# index 533
# label -1
# extraLabel 414
# label -1
# extraLabel 415
# label 3
# index 534
# label 2
# index 535
# label 2
# index 536
# label 2
# index 537
# label -1
# extraLabel 416
# label -1
# extraLabel 417
# label -1
# extraLabel 418
# label 2
# index 538
# label -1
# extraLabel 419
# label 2
# index 539
# label 2
# index 540
# label 2
# index 541
# label 2
# index 542
# label 2
# index 543
# label 2
# index 544
# label 2
# index 545
# label 2
# index 546
# label 2
# index 547
# label 2
# index 548
# label 2
# index 549
# label 2
# index 550
# label 2
# index 551
# label 2
# index 552
# label 2
# index 553
# label -1
# extraLabel 420
# label 2
# index 554
# label -1
# extraLabel 421
# label -1
# extraLabel 422
# label 1
# index 555
# label 1
# index 556
# label 1
# index 557
# label 1
# index 558
# label 1
# index 559
# label 1
# index 560
# label 1
# index 561
# label 1
# index 562
# label 1
# index 563
# label 1
# index 564
# label 1
# index 565
# label 1
# index 566
# label 1
# index 567
# label 1
# index 568
# label 1
# index 569
# label 3
# index 570
# label 3
# index 571
# label 1
# index 572
# label 1
# index 573
# label 3
# index 574
# label 1
# index 575
# label 1
# index 576
# label 1
# index 577
# label 1
# index 578
# label 1
# index 579
# label 1
# index 580
# label 1
# index 581
# label -1
# extraLabel 423
# label 3
# index 582
# label 1
# index 583
# label 1
# index 584
# label 3
# index 585
# label 1
# index 586
# label 1
# index 587
# label -1
# extraLabel 424
# label 1
# index 588
# label 1
# index 589
# label 1
# index 590
# label 1
# index 591
# label 3
# index 592
# label 1
# index 593
# label 1
# index 594
# label 1
# index 595
# label 3
# index 596
# label 1
# index 597
# label 1
# index 598
# label 3
# index 599
# label 1
# index 600
# label 1
# index 601
# label 1
# index 602
# label -1
# extraLabel 425
# label 3
# index 603
# label -1
# extraLabel 426
# label 3
# index 604
# label 3
# index 605
# label 3
# index 606
# label 3
# index 607
# label 3
# index 608
# label 3
# index 609
# label 3
# index 610
# label 3
# index 611
# label 3
# index 612
# label 3
# index 613
# label 3
# index 614
# label 3
# index 615
# label 3
# index 616
# label 3
# index 617
# label 3
# index 618
# label 3
# index 619
# label 3
# index 620
# label 3
# index 621
# label 3
# index 622
# label 3
# index 623
# label 3
# index 624
# label 3
# index 625
# label -1
# extraLabel 427
# label 3
# index 626
# label -1
# extraLabel 428
# label -1
# extraLabel 429
# label -1
# extraLabel 430
# label -1
# extraLabel 431
# label -1
# extraLabel 432
# label -1
# extraLabel 433
# label -1
# extraLabel 434
# label -1
# extraLabel 435
# label -1
# extraLabel 436
# label -1
# extraLabel 437
# label -1
# extraLabel 438
# label -1
# extraLabel 439
# label -1
# extraLabel 440
# label -1
# extraLabel 441
# label 0
# index 627
# label -1
# extraLabel 442
# label -1
# extraLabel 443
# label -1
# extraLabel 444
# label 0
# index 628
# label -1
# extraLabel 445
# label -1
# extraLabel 446
# label -1
# extraLabel 447
# label -1
# extraLabel 448
# label 0
# index 629
# label -1
# extraLabel 449
# label 3
# index 630
# label 3
# index 631
# label 3
# index 632
# label 3
# index 633
# label 3
# index 634
# label 3
# index 635
# label 3
# index 636
# label 3
# index 637
# label 3
# index 638
# label -1
# extraLabel 450
# label -1
# extraLabel 451
# label -1
# extraLabel 452
# label 3
# index 639
# label 3
# index 640
# label 3
# index 641
# label 3
# index 642
# label 3
# index 643
# label 3
# index 644
# label 3
# index 645
# label 3
# index 646
# label 3
# index 647
# label 3
# index 648
# label 3
# index 649
# label 3
# index 650
# label 3
# index 651
# label 3
# index 652
# label 3
# index 653
# label 3
# index 654
# label 3
# index 655
# label 3
# index 656
# label 3
# index 657
# label 3
# index 658
# label 3
# index 659
# label 3
# index 660
# label 3
# index 661
# label 3
# index 662
# label -1
# extraLabel 453
# label -1
# extraLabel 454
# label -1
# extraLabel 455
# label -1
# extraLabel 456
# label -1
# extraLabel 457
# label -1
# extraLabel 458
# label -1
# extraLabel 459
# label 0
# index 663
# label 0
# index 664
# label 0
# index 665
# label 0
# index 666
# label 0
# index 667
# label -1
# extraLabel 460
# label -1
# extraLabel 461
# label -1
# extraLabel 462
# label -1
# extraLabel 463
# label -1
# extraLabel 464
# label -1
# extraLabel 465
# label 3
# index 668
# label -1
# extraLabel 466
# label -1
# extraLabel 467
# label -1
# extraLabel 468
# label -1
# extraLabel 469
# label 0
# index 669
# label 0
# index 670
# label 0
# index 671
# label 0
# index 672
# label 0
# index 673
# label 0
# index 674
# label 0
# index 675
# label 0
# index 676
# label 0
# index 677
# label -1
# extraLabel 470
# label -1
# extraLabel 471
# label 0
# index 678
# label 3
# index 679
# label 3
# index 680
# label 3
# index 681
# label 2
# index 682
# label 2
# index 683
# label 2
# index 684
# label 2
# index 685
# label 3
# index 686
# label 3
# index 687
# label 3
# index 688
# label 3
# index 689
# label 3
# index 690
# label 3
# index 691
# label 3
# index 692
# label 3
# index 693
# label 3
# index 694
# label 3
# index 695
# label 3
# index 696
# label 3
# index 697
# label 3
# index 698
# label 3
# index 699
# label 3
# index 700
# label 3
# index 701
# label 3
# index 702
# label 3
# index 703
# label 3
# index 704
# label 3
# index 705
# label 3
# index 706
# label 3
# index 707
# label 2
# index 708
# label 2
# index 709
# label 2
# index 710
# label 2
# index 711
# label 2
# index 712
# label 2
# index 713
# label 2
# index 714
# label 2
# index 715
# label 2
# index 716
# label 2
# index 717
# label 2
# index 718
# label 2
# index 719
# label 2
# index 720
# label 2
# index 721
# label 2
# index 722
# label 2
# index 723
# label 2
# index 724
# label 2
# index 725
# label 2
# index 726
# label 2
# index 727
# label 2
# index 728
# label 2
# index 729
# label 2
# index 730
# label 2
# index 731
# label 2
# index 732
# label 2
# index 733
# label 2
# index 734
# label 2
# index 735
# label 2
# index 736
# label 2
# index 737
# label 2
# index 738
# label 3
# index 739
# label 1
# index 740
# label -1
# extraLabel 472
# label 1
# index 741
# label 1
# index 742
# label 1
# index 743
# label 1
# index 744
# label 1
# index 745
# label 1
# index 746
# label 1
# index 747
# label 3
# index 748
# label 1
# index 749
# label 3
# index 750
# label 1
# index 751
# label 1
# index 752
# label 1
# index 753
# label 1
# index 754
# label -1
# extraLabel 473
# label 1
# index 755
# label -1
# extraLabel 474
# label 3
# index 756
# label 1
# index 757
# label 1
# index 758
# label 1
# index 759
# label 1
# index 760
# label 1
# index 761
# label 1
# index 762
# label 1
# index 763
# label -1
# extraLabel 475
# label -1
# extraLabel 476
# label -1
# extraLabel 477
# label -1
# extraLabel 478
# label -1
# extraLabel 479
# label 1
# index 764
# label 1
# index 765
# label 1
# index 766
# label 1
# index 767
# label 1
# index 768
# label 1
# index 769
# label 1
# index 770
# label 1
# index 771
# label 1
# index 772
# label 1
# index 773
# label 1
# index 774
# label 1
# index 775
# label 1
# index 776
# label 1
# index 777
# label -1
# extraLabel 480
# label 1
# index 778
# label -1
# extraLabel 481
# label -1
# extraLabel 482
# label -1
# extraLabel 483
# label 1
# index 779
# label 1
# index 780
# label 1
# index 781
# label 3
# index 782
# label -1
# extraLabel 484
# label -1
# extraLabel 485
# label -1
# extraLabel 486
# label 1
# index 783
# label -1
# extraLabel 487
# label 3
# index 784
# label -1
# extraLabel 488
# label -1
# extraLabel 489
# label -1
# extraLabel 490
# label 3
# index 785
# label -1
# extraLabel 491
# label 1
# index 786
# label 1
# index 787
# label -1
# extraLabel 492
# label -1
# extraLabel 493
# label -1
# extraLabel 494
# label -1
# extraLabel 495
# label 2
# index 788
# label 2
# index 789
# label 2
# index 790
# label -1
# extraLabel 496
# label 0
# index 791
# label -1
# extraLabel 497
# label -1
# extraLabel 498
# label 0
# index 792
# label -1
# extraLabel 499
# label -1
# extraLabel 500
# label 0
# index 793
# label 0
# index 794
# label 0
# index 795
# label 0
# index 796
# label -1
# extraLabel 501
# label -1
# extraLabel 502
# label 0
# index 797
# label -1
# extraLabel 503
# label -1
# extraLabel 504
# label 0
# index 798
# label 0
# index 799
# label 3
# index 800
# label 3
# index 801
# label -1
# extraLabel 505
# label -1
# extraLabel 506
# label 0
# index 802
# label 0
# index 803
# label 2
# index 804
# label 0
# index 805
# label -1
# extraLabel 507
# label -1
# extraLabel 508
# label 0
# index 806
# label 0
# index 807
# label 0
# index 808
# label -1
# extraLabel 509
# label 0
# index 809
# label 0
# index 810
# label 0
# index 811
# label 0
# index 812
# label 0
# index 813
# label 3
# index 814
# label -1
# extraLabel 510
# label 3
# index 815
# label 2
# index 816
# label 2
# index 817
# label 2
# index 818
# label 2
# index 819
# label 2
# index 820
# label -1
# extraLabel 511
# label -1
# extraLabel 512
# label -1
# extraLabel 513
# label -1
# extraLabel 514
# label -1
# extraLabel 515
# label -1
# extraLabel 516
# label -1
# extraLabel 517
# label -1
# extraLabel 518
# label -1
# extraLabel 519
# label 3
# index 821
# label -1
# extraLabel 520
# label -1
# extraLabel 521
# label 0
# index 822
# label 0
# index 823
# label -1
# extraLabel 522
# label 0
# index 824
# label 2
# index 825
# label -1
# extraLabel 523
# label -1
# extraLabel 524
# label -1
# extraLabel 525
# label -1
# extraLabel 526
# label -1
# extraLabel 527
# label -1
# extraLabel 528
# label -1
# extraLabel 529
# label -1
# extraLabel 530
# label -1
# extraLabel 531
# label 0
# index 826
# label 0
# index 827
# label -1
# extraLabel 532
# label 3
# index 828
# label 2
# index 829
# label -1
# extraLabel 533
# label 2
# index 830
# label 0
# index 831
# label 2
# index 832
# label 0
# index 833
# label 0
# index 834
# label -1
# extraLabel 534
# label -1
# extraLabel 535
# label 0
# index 835
# label 0
# index 836
# label -1
# extraLabel 536
# label -1
# extraLabel 537
# label -1
# extraLabel 538
# label 0
# index 837
# label -1
# extraLabel 539
# label 0
# index 838
# label 0
# index 839
# label 0
# index 840
# label -1
# extraLabel 540
# label 3
# index 841
# label 3
# index 842
# label -1
# extraLabel 541
# label -1
# extraLabel 542
# label -1
# extraLabel 543
# label -1
# extraLabel 544
# label -1
# extraLabel 545
# label 3
# index 843
# label -1
# extraLabel 546
# label -1
# extraLabel 547
# label -1
# extraLabel 548
# label -1
# extraLabel 549
# label -1
# extraLabel 550
# label -1
# extraLabel 551
# label -1
# extraLabel 552
# label 0
# index 844
# label 0
# index 845
# label 0
# index 846
# label 3
# index 847
# label 3
# index 848
# label -1
# extraLabel 553
# label 2
# index 849
# label 3
# index 850
# label 2
# index 851
# label 2
# index 852
# label -1
# extraLabel 554
# label 3
# index 853
# label -1
# extraLabel 555
# label -1
# extraLabel 556
# label -1
# extraLabel 557
# label 3
# index 854
# label -1
# extraLabel 558
# label 1
# index 855
# label 1
# index 856
# label 1
# index 857
# label -1
# extraLabel 559
# label 2
# index 858
# label 2
# index 859
# label -1
# extraLabel 560
# label 2
# index 860
# label 2
# index 861
# label 2
# index 862
# label 2
# index 863
# label 2
# index 864
# label 2
# index 865
# label -1
# extraLabel 561
# label -1
# extraLabel 562
# label -1
# extraLabel 563
# label 1
# index 866
# label 1
# index 867
# label 1
# index 868
# label 2
# index 869
# label -1
# extraLabel 564
# label 3
# index 870
# label -1
# extraLabel 565
# label 3
# index 871
# label 3
# index 872
# label -1
# extraLabel 566
# label 1
# index 873
# label -1
# extraLabel 567
# label -1
# extraLabel 568
# label -1
# extraLabel 569
# label -1
# extraLabel 570
# label 3
# index 874
# label -1
# extraLabel 571
# label 1
# index 875
# label -1
# extraLabel 572
# label 1
# index 876
# label 1
# index 877
# label 2
# index 878
# label 2
# index 879
# label 2
# index 880
# label 2
# index 881
# label 2
# index 882
# label 2
# index 883
# label 2
# index 884
# label 2
# index 885
# label 2
# index 886
# label 2
# index 887
# label 2
# index 888
# label 2
# index 889
# label 2
# index 890
# label 2
# index 891
# label 2
# index 892
# label 2
# index 893
# label 2
# index 894
# label 2
# index 895
# label 2
# index 896
# label 2
# index 897
# label 2
# index 898
# label 2
# index 899
# label -1
# extraLabel 573
# label 1
# index 900
# label -1
# extraLabel 574
# label -1
# extraLabel 575
# label -1
# extraLabel 576
# label -1
# extraLabel 577
# label -1
# extraLabel 578
# label 0
# index 901
# label -1
# extraLabel 579
# label 3
# index 902
# label 3
# index 903
# label 1
# index 904
# label -1
# extraLabel 580
# label -1
# extraLabel 581
# label -1
# extraLabel 582
# label -1
# extraLabel 583
# label 0
# index 905
# label -1
# extraLabel 584
# label -1
# extraLabel 585
# label 0
# index 906
# label -1
# extraLabel 586
# label -1
# extraLabel 587
# label -1
# extraLabel 588
# label 0
# index 907
# label 0
# index 908
# label 0
# index 909
# label -1
# extraLabel 589
# label 1
# index 910
# label 1
# index 911
# label 1
# index 912
# label -1
# extraLabel 590
# label 1
# index 913
# label 1
# index 914
# label -1
# extraLabel 591
# label 3
# index 915
# label -1
# extraLabel 592
# label 3
# index 916
# label 3
# index 917
# label 3
# index 918
# label -1
# extraLabel 593
# label -1
# extraLabel 594
# label 1
# index 919
# label -1
# extraLabel 595
# label 1
# index 920
# label 1
# index 921
# label -1
# extraLabel 596
# label -1
# extraLabel 597
# label -1
# extraLabel 598
# label -1
# extraLabel 599
# label 3
# index 922
# label 3
# index 923
# label -1
# extraLabel 600
# label -1
# extraLabel 601
# label -1
# extraLabel 602
# label -1
# extraLabel 603
# label 0
# index 924
# label -1
# extraLabel 604
# label 3
# index 925
# label 1
# index 926
# label 1
# index 927
# label -1
# extraLabel 605
# label -1
# extraLabel 606
# label -1
# extraLabel 607
# label -1
# extraLabel 608
# label 3
# index 928
# label -1
# extraLabel 609
# label 3
# index 929
# label 1
# index 930
# label 1
# index 931
# label 1
# index 932
# label 1
# index 933
# label 1
# index 934
# label 1
# index 935
# label 1
# index 936
# label 3
# index 937
# label -1
# extraLabel 610
# label -1
# extraLabel 611
# label -1
# extraLabel 612
# label -1
# extraLabel 613
# label -1
# extraLabel 614
# label -1
# extraLabel 615
# label -1
# extraLabel 616
# label -1
# extraLabel 617
# label -1
# extraLabel 618
# label 0
# index 938
# label 0
# index 939
# label -1
# extraLabel 619
# label 0
# index 940
# label 0
# index 941
# label 0
# index 942
# label 0
# index 943
# label -1
# extraLabel 620
# label -1
# extraLabel 621
# label 3
# index 944
# label -1
# extraLabel 622
# label -1
# extraLabel 623
# label 2
# index 945
# label -1
# extraLabel 624
# label 2
# index 946
# label 2
# index 947
# label 2
# index 948
# label -1
# extraLabel 625
# label -1
# extraLabel 626
# label -1
# extraLabel 627
# label 0
# index 949
# label 0
# index 950
# label 0
# index 951
# label 2
# index 952
# label 2
# index 953
# label 2
# index 954
# label 2
# index 955
# label 2
# index 956
# label -1
# extraLabel 628
# label -1
# extraLabel 629
# label 2
# index 957
# label -1
# extraLabel 630
# label -1
# extraLabel 631
# label -1
# extraLabel 632
# label 1
# index 958
# label 1
# index 959
# label 2
# index 960
# label 3
# index 961
# label -1
# extraLabel 633
# label 1
# index 962
# label 1
# index 963
# label 1
# index 964
# label -1
# extraLabel 634
# label -1
# extraLabel 635
# label -1
# extraLabel 636
# label -1
# extraLabel 637
# label 3
# index 965
# label -1
# extraLabel 638
# label -1
# extraLabel 639
# label -1
# extraLabel 640
# label -1
# extraLabel 641
# label 3
# index 966
# label -1
# extraLabel 642
# label -1
# extraLabel 643
# label -1
# extraLabel 644
# label -1
# extraLabel 645
# label -1
# extraLabel 646
# label 3
# index 967
# label 3
# index 968
# label 3
# index 969
# label 3
# index 970
# label 3
# index 971
# label -1
# extraLabel 647
# label 3
# index 972
# label -1
# extraLabel 648
# label 3
# index 973
# label 3
# index 974
# label 3
# index 975
# label 3
# index 976
# label -1
# extraLabel 649
# label -1
# extraLabel 650
# label 0
# index 977
# label -1
# extraLabel 651
# label 0
# index 978
# label -1
# extraLabel 652
# label 2
# index 979
# label 2
# index 980
# label 3
# index 981
# label 3
# index 982
# label 2
# index 983
# label 2
# index 984
# label 2
# index 985
# label 2
# index 986
# label 2
# index 987
# label -1
# extraLabel 653
# label -1
# extraLabel 654
# label -1
# extraLabel 655
# label 1
# index 988
# label 3
# index 989
# label 3
# index 990
# label 1
# index 991
# label 1
# index 992
# label 3
# index 993
# label -1
# extraLabel 656
# label -1
# extraLabel 657
# label -1
# extraLabel 658
# label 1
# index 994
# label 1
# index 995
# label -1
# extraLabel 659
# label -1
# extraLabel 660
# label 1
# index 996
# label 1
# index 997
# label 1
# index 998
# label 1
# index 999
# label 1
# index 1000
# label -1
# extraLabel 661
# label -1
# extraLabel 662
# label 1
# index 1001
# label 1
# index 1002
# label -1
# extraLabel 663
# label 1
# index 1003
# label 1
# index 1004
# label 1
# index 1005
# label -1
# extraLabel 664
# label 1
# index 1006
# label -1
# extraLabel 665
# label -1
# extraLabel 666
# label 1
# index 1007
# label -1
# extraLabel 667
# label -1
# extraLabel 668
# label -1
# extraLabel 669
# label -1
# extraLabel 670
# label -1
# extraLabel 671
# label 1
# index 1008
# label 1
# index 1009
# label -1
# extraLabel 672
# label -1
# extraLabel 673
# label 1
# index 1010
# label -1
# extraLabel 674
# label 1
# index 1011
# label 1
# index 1012
# label 1
# index 1013
# label 1
# index 1014
# label 1
# index 1015
# label 1
# index 1016
# label -1
# extraLabel 675
# label -1
# extraLabel 676
# label -1
# extraLabel 677
# label -1
# extraLabel 678
# label 1
# index 1017
# label -1
# extraLabel 679
# label -1
# extraLabel 680
# label -1
# extraLabel 681
# label -1
# extraLabel 682
# label -1
# extraLabel 683
# label 1
# index 1018
# label 1
# index 1019
# label 1
# index 1020
# label 1
# index 1021
# label 2
# index 1022
# label -1
# extraLabel 684
# label 1
# index 1023
# label 1
# index 1024
# label -1
# extraLabel 685
# label 1
# index 1025
# label -1
# extraLabel 686
# label 1
# index 1026
# label 1
# index 1027
# label -1
# extraLabel 687
# label -1
# extraLabel 688
# label -1
# extraLabel 689
# label -1
# extraLabel 690
# label -1
# extraLabel 691
# label 1
# index 1028
# label 1
# index 1029
# label 1
# index 1030
# label 1
# index 1031
# label -1
# extraLabel 692
# label 1
# index 1032
# label -1
# extraLabel 693
# label -1
# extraLabel 694
# label -1
# extraLabel 695
# label 1
# index 1033
# label -1
# extraLabel 696
# label 1
# index 1034
# label 1
# index 1035
# label 1
# index 1036
# label -1
# extraLabel 697
# label -1
# extraLabel 698
# label -1
# extraLabel 699
# label -1
# extraLabel 700
# label -1
# extraLabel 701
# label -1
# extraLabel 702
# label -1
# extraLabel 703
# label 3
# index 1037
# label -1
# extraLabel 704
# label -1
# extraLabel 705
# label -1
# extraLabel 706
# label 3
# index 1038
# label 0
# index 1039
# label -1
# extraLabel 707
# label -1
# extraLabel 708
# label -1
# extraLabel 709
# label 0
# index 1040
# label -1
# extraLabel 710
# label 0
# index 1041
# label -1
# extraLabel 711
# label -1
# extraLabel 712
# label -1
# extraLabel 713
# label -1
# extraLabel 714
# label 0
# index 1042
# label 0
# index 1043
# label 0
# index 1044
# label 0
# index 1045
# label 0
# index 1046
# label 0
# index 1047
# label 0
# index 1048
# label 0
# index 1049
# label 0
# index 1050
# label 0
# index 1051
# label -1
# extraLabel 715
# label 0
# index 1052
# label 0
# index 1053
# label 0
# index 1054
# label 0
# index 1055
# label 0
# index 1056
# label 0
# index 1057
# label 0
# index 1058
# label 0
# index 1059
# label 0
# index 1060
# label -1
# extraLabel 716
# label -1
# extraLabel 717
# label -1
# extraLabel 718
# label -1
# extraLabel 719
# label -1
# extraLabel 720
# label -1
# extraLabel 721
# label -1
# extraLabel 722
# label -1
# extraLabel 723
# label -1
# extraLabel 724
# label -1
# extraLabel 725
# label -1
# extraLabel 726
# label -1
# extraLabel 727
# label 3
# index 1061
# label 3
# index 1062
# label -1
# extraLabel 728
# label -1
# extraLabel 729
# label -1
# extraLabel 730
# label -1
# extraLabel 731
# label 3
# index 1063
# label -1
# extraLabel 732
# label -1
# extraLabel 733
# label -1
# extraLabel 734
# label 0
# index 1064
# label 0
# index 1065
# label 0
# index 1066
# label 0
# index 1067
# label 0
# index 1068
# label 0
# index 1069
# label 0
# index 1070
# label 0
# index 1071
# label 0
# index 1072
# label 0
# index 1073
# label 0
# index 1074
# label 0
# index 1075
# label 0
# index 1076
# label 0
# index 1077
# label 0
# index 1078
# label 0
# index 1079
# label 0
# index 1080
# label 0
# index 1081
# label 0
# index 1082
# label 0
# index 1083
# label 0
# index 1084
# label 0
# index 1085
# label 3
# index 1086
# label -1
# extraLabel 735
# label -1
# extraLabel 736
# label -1
# extraLabel 737
# label -1
# extraLabel 738
# label -1
# extraLabel 739
# label -1
# extraLabel 740
# label -1
# extraLabel 741
# label -1
# extraLabel 742
# label -1
# extraLabel 743
# label -1
# extraLabel 744
# label -1
# extraLabel 745
# label -1
# extraLabel 746
# label -1
# extraLabel 747
# label -1
# extraLabel 748
# label -1
# extraLabel 749
# label -1
# extraLabel 750
# label -1
# extraLabel 751
# label 0
# index 1087
# label 0
# index 1088
# label 0
# index 1089
# label 0
# index 1090
# label -1
# extraLabel 752
# label -1
# extraLabel 753
# label 3
# index 1091
# label 3
# index 1092
# label 3
# index 1093
# label -1
# extraLabel 754
# label 3
# index 1094
# label -1
# extraLabel 755
# label -1
# extraLabel 756
# label -1
# extraLabel 757
# label -1
# extraLabel 758
# label -1
# extraLabel 759
# label -1
# extraLabel 760
# label -1
# extraLabel 761
# label -1
# extraLabel 762
# label -1
# extraLabel 763
# label -1
# extraLabel 764
# label -1
# extraLabel 765
# label -1
# extraLabel 766
# label 0
# index 1095
# label -1
# extraLabel 767
# label 0
# index 1096
# label -1
# extraLabel 768
# label -1
# extraLabel 769
# label -1
# extraLabel 770
# label -1
# extraLabel 771
# label -1
# extraLabel 772
# label 2
# index 1097
# label 2
# index 1098
# label 2
# index 1099
# label 2
# index 1100
# label 2
# index 1101
# label 2
# index 1102
# label 2
# index 1103
# label 2
# index 1104
# label 2
# index 1105
# label 2
# index 1106
# label 2
# index 1107
# label 2
# index 1108
# label 2
# index 1109
# label 2
# index 1110
# label -1
# extraLabel 773
# label -1
# extraLabel 774
# label -1
# extraLabel 775
# label -1
# extraLabel 776
# label -1
# extraLabel 777
# label -1
# extraLabel 778
# label -1
# extraLabel 779
# label 2
# index 1111
# label -1
# extraLabel 780
# label -1
# extraLabel 781
# label -1
# extraLabel 782
# label -1
# extraLabel 783
# label 2
# index 1112
# label 1
# index 1113
# label 1
# index 1114
# label -1
# extraLabel 784
# label -1
# extraLabel 785
# label 1
# index 1115
# label -1
# extraLabel 786
# label -1
# extraLabel 787
# label -1
# extraLabel 788
# label -1
# extraLabel 789
# label 1
# index 1116
# label -1
# extraLabel 790
# label 1
# index 1117
# label 1
# index 1118
# label 1
# index 1119
# label 1
# index 1120
# label 1
# index 1121
# label 1
# index 1122
# label 1
# index 1123
# label 1
# index 1124
# label 1
# index 1125
# label -1
# extraLabel 791
# label 1
# index 1126
# label -1
# extraLabel 792
# label 1
# index 1127
# label 1
# index 1128
# label -1
# extraLabel 793
# label 1
# index 1129
# label 1
# index 1130
# label 1
# index 1131
# label 1
# index 1132
# label 1
# index 1133
# label -1
# extraLabel 794
# label 3
# index 1134
# label -1
# extraLabel 795
# label -1
# extraLabel 796
# label 1
# index 1135
# label 1
# index 1136
# label -1
# extraLabel 797
# label -1
# extraLabel 798
# label -1
# extraLabel 799
# label 1
# index 1137
# label 1
# index 1138
# label 1
# index 1139
# label 1
# index 1140
# label 3
# index 1141
# label 3
# index 1142
# label 3
# index 1143
# label 3
# index 1144
# label 3
# index 1145
# label 3
# index 1146
# label 1
# index 1147
# label 1
# index 1148
# label -1
# extraLabel 800
# label 1
# index 1149
# label 1
# index 1150
# label 1
# index 1151
# label 1
# index 1152
# label 1
# index 1153
# label -1
# extraLabel 801
# label -1
# extraLabel 802
# label -1
# extraLabel 803
# label -1
# extraLabel 804
# label -1
# extraLabel 805
# label -1
# extraLabel 806
# label -1
# extraLabel 807
# label -1
# extraLabel 808
# label -1
# extraLabel 809
# label 2
# index 1154
# label -1
# extraLabel 810
# label -1
# extraLabel 811
# label -1
# extraLabel 812
# label -1
# extraLabel 813
# label -1
# extraLabel 814
# label -1
# extraLabel 815
# label 2
# index 1155
# label -1
# extraLabel 816
# label 3
# index 1156
# label 3
# index 1157
# label -1
# extraLabel 817
# label 3
# index 1158
# label 3
# index 1159
# label 3
# index 1160
# label 3
# index 1161
# label 3
# index 1162
# label 3
# index 1163
# label 3
# index 1164
# label 3
# index 1165
# label 3
# index 1166
# label 3
# index 1167
# label 3
# index 1168
# label -1
# extraLabel 818
# label 3
# index 1169
# label 3
# index 1170
# label 3
# index 1171
# label 3
# index 1172
# label 3
# index 1173
# label -1
# extraLabel 819
# label 3
# index 1174
# label 3
# index 1175
# label -1
# extraLabel 820
# label -1
# extraLabel 821
# label 3
# index 1176
# label -1
# extraLabel 822
# label 0
# index 1177
# label -1
# extraLabel 823
# label -1
# extraLabel 824
# label -1
# extraLabel 825
# label 0
# index 1178
# label -1
# extraLabel 826
# label -1
# extraLabel 827
# label -1
# extraLabel 828
# label -1
# extraLabel 829
# label -1
# extraLabel 830
# label -1
# extraLabel 831
# label -1
# extraLabel 832
# label -1
# extraLabel 833
# label 0
# index 1179
# label -1
# extraLabel 834
# label -1
# extraLabel 835
# label -1
# extraLabel 836
# label 3
# index 1180
# label 3
# index 1181
# label 3
# index 1182
# label 3
# index 1183
# label 3
# index 1184
# label 3
# index 1185
# label 3
# index 1186
# label 3
# index 1187
# label 3
# index 1188
# label 3
# index 1189
# label 3
# index 1190
# label 3
# index 1191
# label 3
# index 1192
# label 3
# index 1193
# label 3
# index 1194
# label 3
# index 1195
# label 3
# index 1196
# label 3
# index 1197
# label 3
# index 1198
# label 3
# index 1199
# label 3
# index 1200
# label 3
# index 1201
# label 2
# index 1202
# label 2
# index 1203
# label 2
# index 1204
# label 2
# index 1205
# label 2
# index 1206
# label 2
# index 1207
# label 2
# index 1208
# label 2
# index 1209
# label 2
# index 1210
# label 2
# index 1211
# label 2
# index 1212
# label 2
# index 1213
# label 2
# index 1214
# label 2
# index 1215
# label 2
# index 1216
# label 3
# index 1217
# label 3
# index 1218
# label 3
# index 1219
# label 3
# index 1220
# label 3
# index 1221
# label 3
# index 1222
# label 3
# index 1223
# label 3
# index 1224
# label 3
# index 1225
# label 3
# index 1226
# label 3
# index 1227
# label 3
# index 1228
# label 3
# index 1229
# label 3
# index 1230
# label 3
# index 1231
# label 3
# index 1232
# label 3
# index 1233
# label 3
# index 1234
# label 3
# index 1235
# label 3
# index 1236
# label -1
# extraLabel 837
# label 1
# index 1237
# label 1
# index 1238
# label 1
# index 1239
# label 1
# index 1240
# label 1
# index 1241
# label 1
# index 1242
# label 1
# index 1243
# label 1
# index 1244
# label 1
# index 1245
# label 1
# index 1246
# label 1
# index 1247
# label 1
# index 1248
# label 1
# index 1249
# label 1
# index 1250
# label 1
# index 1251
# label 1
# index 1252
# label 1
# index 1253
# label 1
# index 1254
# label 1
# index 1255
# label 1
# index 1256
# label 1
# index 1257
# label 1
# index 1258
# label 1
# index 1259
# label 1
# index 1260
# label 1
# index 1261
# label 1
# index 1262
# label 1
# index 1263
# label 1
# index 1264
# label 1
# index 1265
# label 1
# index 1266
# label 1
# index 1267
# label 1
# index 1268
# label 1
# index 1269
# label 1
# index 1270
# label 1
# index 1271
# label 1
# index 1272
# label 1
# index 1273
# label 3
# index 1274
# label 1
# index 1275
# label 1
# index 1276
# label 1
# index 1277
# label 1
# index 1278
# label 1
# index 1279
# label 1
# index 1280
# label 1
# index 1281
# label 1
# index 1282
# label 1
# index 1283
# label 1
# index 1284
# label 1
# index 1285
# label -1
# extraLabel 838
# label -1
# extraLabel 839
# label -1
# extraLabel 840
# label -1
# extraLabel 841
# label 3
# index 1286
# label 1
# index 1287
# label 1
# index 1288
# label 1
# index 1289
# label -1
# extraLabel 842
# label -1
# extraLabel 843
# label -1
# extraLabel 844
# label 1
# index 1290
# label -1
# extraLabel 845
# label -1
# extraLabel 846
# label -1
# extraLabel 847
# label 1
# index 1291
# label 1
# index 1292
# label 1
# index 1293
# label -1
# extraLabel 848
# label -1
# extraLabel 849
# label -1
# extraLabel 850
# label -1
# extraLabel 851
# label 1
# index 1294
# label -1
# extraLabel 852
# label 3
# index 1295
# label 3
# index 1296
# label 3
# index 1297
# label 3
# index 1298
# label 3
# index 1299
# label 3
# index 1300
# label 3
# index 1301
# label 3
# index 1302
# label 3
# index 1303
# label 3
# index 1304
# label 3
# index 1305
# label 3
# index 1306
# label 3
# index 1307
# label 3
# index 1308
# label 3
# index 1309
# label 3
# index 1310
# label 3
# index 1311
# label 3
# index 1312
# label 3
# index 1313
# label 3
# index 1314
# label 3
# index 1315
# label 3
# index 1316
# label 3
# index 1317
# label 3
# index 1318
# label 3
# index 1319
# label 3
# index 1320
# label 3
# index 1321
# label 3
# index 1322
# label -1
# extraLabel 853
# label -1
# extraLabel 854
# label -1
# extraLabel 855
# label 3
# index 1323
# label -1
# extraLabel 856
# label 3
# index 1324
# label 3
# index 1325
# label 3
# index 1326
# label 3
# index 1327
# label 3
# index 1328
# label 3
# index 1329
# label 3
# index 1330
# label 3
# index 1331
# label 3
# index 1332
# label -1
# extraLabel 857
# label 3
# index 1333
# label 3
# index 1334
# label -1
# extraLabel 858
# label 3
# index 1335
# label 3
# index 1336
# label -1
# extraLabel 859
# label -1
# extraLabel 860
# label -1
# extraLabel 861
# label -1
# extraLabel 862
# label 2
# index 1337
# label 2
# index 1338
# label 2
# index 1339
# label -1
# extraLabel 863
# label -1
# extraLabel 864
# label -1
# extraLabel 865
# label -1
# extraLabel 866
# label -1
# extraLabel 867
# label -1
# extraLabel 868
# label -1
# extraLabel 869
# label -1
# extraLabel 870
# label -1
# extraLabel 871
# label -1
# extraLabel 872
# label 2
# index 1340
# label 3
# index 1341
# label 0
# index 1342
# label -1
# extraLabel 873
# label 3
# index 1343
# label -1
# extraLabel 874
# label -1
# extraLabel 875
# label -1
# extraLabel 876
# label 3
# index 1344
# label 3
# index 1345
# label 3
# index 1346
# label 2
# index 1347
# label -1
# extraLabel 877
# label -1
# extraLabel 878
# label -1
# extraLabel 879
# label -1
# extraLabel 880
# label -1
# extraLabel 881
# label -1
# extraLabel 882
# label -1
# extraLabel 883
# label 0
# index 1348
# label 0
# index 1349
# label 0
# index 1350
# label -1
# extraLabel 884
# label 0
# index 1351
# label -1
# extraLabel 885
# label -1
# extraLabel 886
# label -1
# extraLabel 887
# label 2
# index 1352
# label -1
# extraLabel 888
# label -1
# extraLabel 889
# label -1
# extraLabel 890
# label -1
# extraLabel 891
# label -1
# extraLabel 892
# label -1
# extraLabel 893
# label -1
# extraLabel 894
# label -1
# extraLabel 895
# label -1
# extraLabel 896
# label -1
# extraLabel 897
# label -1
# extraLabel 898
# label 0
# index 1353
# label -1
# extraLabel 899
# label 0
# index 1354
# label -1
# extraLabel 900
# label -1
# extraLabel 901
# label -1
# extraLabel 902
# label 3
# index 1355
# label -1
# extraLabel 903
# label -1
# extraLabel 904
# label -1
# extraLabel 905
# label 0
# index 1356
# label -1
# extraLabel 906
# label 0
# index 1357
# label -1
# extraLabel 907
# label 0
# index 1358
# label -1
# extraLabel 908
# label 2
# index 1359
# label -1
# extraLabel 909
# label 3
# index 1360
# label -1
# extraLabel 910
# label -1
# extraLabel 911
# label -1
# extraLabel 912
# label -1
# extraLabel 913
# label -1
# extraLabel 914
# label -1
# extraLabel 915
# label 0
# index 1361
# label 0
# index 1362
# label 0
# index 1363
# label -1
# extraLabel 916
# label 3
# index 1364
# label -1
# extraLabel 917
# label -1
# extraLabel 918
# label 3
# index 1365
# label 3
# index 1366
# label -1
# extraLabel 919
# label -1
# extraLabel 920
# label -1
# extraLabel 921
# label -1
# extraLabel 922
# label -1
# extraLabel 923
# label 0
# index 1367
# label -1
# extraLabel 924
# label -1
# extraLabel 925
# label -1
# extraLabel 926
# label -1
# extraLabel 927
# label -1
# extraLabel 928
# label -1
# extraLabel 929
# label 0
# index 1368
# label 0
# index 1369
# label -1
# extraLabel 930
# label -1
# extraLabel 931
# label -1
# extraLabel 932
# label -1
# extraLabel 933
# label -1
# extraLabel 934
# label -1
# extraLabel 935
# label 3
# index 1370
# label 3
# index 1371
# label -1
# extraLabel 936
# label 3
# index 1372
# label 3
# index 1373
# label 3
# index 1374
# label 3
# index 1375
# label 3
# index 1376
# label -1
# extraLabel 937
# label -1
# extraLabel 938
# label -1
# extraLabel 939
# label -1
# extraLabel 940
# label -1
# extraLabel 941
# label -1
# extraLabel 942
# label -1
# extraLabel 943
# label 0
# index 1377
# label 0
# index 1378
# label 0
# index 1379
# label -1
# extraLabel 944
# label -1
# extraLabel 945
# label -1
# extraLabel 946
# label -1
# extraLabel 947
# label -1
# extraLabel 948
# label -1
# extraLabel 949
# label -1
# extraLabel 950
# label -1
# extraLabel 951
# label -1
# extraLabel 952
# label 2
# index 1380
# label -1
# extraLabel 953
# label -1
# extraLabel 954
# label 1
# index 1381
# label 1
# index 1382
# label 1
# index 1383
# label -1
# extraLabel 955
# label 1
# ...
# index 5104
# label 2
# index 5105
# label 2
# index 5106
# label 2
# index 5107
# label 2
# index 5108
# label 2
# index 5109
# label 2
# index 5110
# label 2
# index 5111
# label 2
# index 5112
# label 2
# index 5113
# label 2
# index 5114
# label 2
# index 5115
# label 2
# index 5116
# label 2
# index 5117
# label 2
# index 5118
# label 2
# index 5119
# label 2
# index 5120
# label 2
# index 5121
# label 2
# index 5122
# label 2
# index 5123
# label 2
# index 5124
# label 2
# index 5125
# label 2
# index 5126
# label 2
# index 5127
# label -1
# extraLabel 4194
# label -1
# extraLabel 4195
# label 2
# index 5128
# label 2
# index 5129
# label 2
# index 5130
# label 2
# index 5131
# label 1
# index 5132
# label 1
# index 5133
# label -1
# extraLabel 4196
# label 1
# index 5134
# label 1
# index 5135
# label 1
# index 5136
# label -1
# extraLabel 4197
# label 1
# index 5137
# label 1
# index 5138
# label 1
# index 5139
# label 3
# index 5140
# label 1
# index 5141
# label 1
# index 5142
# label 1
# index 5143
# label -1
# extraLabel 4198
# label 1
# index 5144
# label 3
# index 5145
# label 3
# index 5146
# label 3
# index 5147
# label 3
# index 5148
# label 3
# index 5149
# label 1
# index 5150
# label 1
# index 5151
# label 1
# index 5152
# label 3
# index 5153
# label 3
# index 5154
# label 3
# index 5155
# label 3
# index 5156
# label 3
# index 5157
# label 3
# index 5158
# label 3
# index 5159
# label 1
# index 5160
# label 3
# index 5161
# label 3
# index 5162
# label -1
# extraLabel 4199
# label 1
# index 5163
# label 1
# index 5164
# label 1
# index 5165
# label 3
# index 5166
# label 1
# index 5167
# label 3
# index 5168
# label 1
# index 5169
# label 1
# index 5170
# label -1
# extraLabel 4200
# label 1
# index 5171
# label 1
# index 5172
# label -1
# extraLabel 4201
# label 1
# index 5173
# label 1
# index 5174
# label 1
# index 5175
# label 1
# index 5176
# label 1
# index 5177
# label 1
# index 5178
# label 1
# index 5179
# label 1
# index 5180
# label -1
# extraLabel 4202
# label 1
# index 5181
# label -1
# extraLabel 4203
# label 1
# index 5182
# label -1
# extraLabel 4204
# label 1
# index 5183
# label 1
# index 5184
# label -1
# extraLabel 4205
# label 1
# index 5185
# label 1
# index 5186
# label 1
# index 5187
# label 1
# index 5188
# label 1
# index 5189
# label 1
# index 5190
# label 1
# index 5191
# label 1
# index 5192
# label 1
# index 5193
# label 1
# index 5194
# label 1
# index 5195
# label -1
# extraLabel 4206
# label 1
# index 5196
# label 1
# index 5197
# label 1
# index 5198
# label 1
# index 5199
# label 1
# index 5200
# label 1
# index 5201
# label 1
# index 5202
# label 1
# index 5203
# label 1
# index 5204
# label 1
# index 5205
# label -1
# extraLabel 4207
# label 1
# index 5206
# label 1
# index 5207
# label 1
# index 5208
# label 1
# index 5209
# label 1
# index 5210
# label 1
# index 5211
# label 1
# index 5212
# label 1
# index 5213
# label 1
# index 5214
# label -1
# extraLabel 4208
# label -1
# extraLabel 4209
# label -1
# extraLabel 4210
# label -1
# extraLabel 4211
# label -1
# extraLabel 4212
# label 3
# index 5215
# label 3
# index 5216
# label 3
# index 5217
# label 3
# index 5218
# label 3
# index 5219
# label -1
# extraLabel 4213
# label 3
# index 5220
# label 3
# index 5221
# label 3
# index 5222
# label 3
# index 5223
# label 3
# index 5224
# label 3
# index 5225
# label 3
# index 5226
# label 3
# index 5227
# label 3
# index 5228
# label -1
# extraLabel 4214
# label -1
# extraLabel 4215
# label 1
# index 5229
# label -1
# extraLabel 4216
# label -1
# extraLabel 4217
# label 1
# index 5230
# label 1
# index 5231
# label 1
# index 5232
# label 1
# index 5233
# label 3
# index 5234
# label 3
# index 5235
# label 3
# index 5236
# label 3
# index 5237
# label 3
# index 5238
# label 3
# index 5239
# label 3
# index 5240
# label 3
# index 5241
# label 3
# index 5242
# label 3
# index 5243
# label 3
# index 5244
# label 3
# index 5245
# label 3
# index 5246
# label 3
# index 5247
# label 3
# index 5248
# label 3
# index 5249
# label 3
# index 5250
# label 3
# index 5251
# label 3
# index 5252
# label 3
# index 5253
# label 3
# index 5254
# label 3
# index 5255
# label 3
# index 5256
# label 3
# index 5257
# label 3
# index 5258
# label 3
# index 5259
# label 1
# index 5260
# label 3
# index 5261
# label 1
# index 5262
# label 2
# index 5263
# label 2
# index 5264
# label -1
# extraLabel 4218
# label -1
# extraLabel 4219
# label 2
# index 5265
# label 2
# index 5266
# label -1
# extraLabel 4220
# label -1
# extraLabel 4221
# label -1
# extraLabel 4222
# label -1
# extraLabel 4223
# label -1
# extraLabel 4224
# label -1
# extraLabel 4225
# label -1
# extraLabel 4226
# label -1
# extraLabel 4227
# label 0
# index 5267
# label -1
# extraLabel 4228
# label -1
# extraLabel 4229
# label -1
# extraLabel 4230
# label 0
# index 5268
# label -1
# extraLabel 4231
# label -1
# extraLabel 4232
# label 0
# index 5269
# label 0
# index 5270
# label 3
# index 5271
# label 3
# index 5272
# label 3
# index 5273
# label 3
# index 5274
# label -1
# extraLabel 4233
# label -1
# extraLabel 4234
# label -1
# extraLabel 4235
# label -1
# extraLabel 4236
# label -1
# extraLabel 4237
# label 0
# index 5275
# label -1
# extraLabel 4238
# label -1
# extraLabel 4239
# label 0
# index 5276
# label 0
# index 5277
# label -1
# extraLabel 4240
# label -1
# extraLabel 4241
# label -1
# extraLabel 4242
# label -1
# extraLabel 4243
# label -1
# extraLabel 4244
# label -1
# extraLabel 4245
# label 2
# index 5278
# label -1
# extraLabel 4246
# label -1
# extraLabel 4247
# label -1
# extraLabel 4248
# label -1
# extraLabel 4249
# label -1
# extraLabel 4250
# label -1
# extraLabel 4251
# label 0
# index 5279
# label -1
# extraLabel 4252
# label 0
# index 5280
# label -1
# extraLabel 4253
# label -1
# extraLabel 4254
# label 3
# index 5281
# label 3
# index 5282
# label -1
# extraLabel 4255
# label -1
# extraLabel 4256
# label 0
# index 5283
# label 0
# index 5284
# label 0
# index 5285
# label 0
# index 5286
# label -1
# extraLabel 4257
# label 0
# index 5287
# label -1
# extraLabel 4258
# label -1
# extraLabel 4259
# label 0
# index 5288
# label -1
# extraLabel 4260
# label -1
# extraLabel 4261
# label -1
# extraLabel 4262
# label 0
# index 5289
# label 0
# index 5290
# label 0
# index 5291
# label 0
# index 5292
# label 0
# index 5293
# label 0
# index 5294
# label -1
# extraLabel 4263
# label -1
# extraLabel 4264
# label -1
# extraLabel 4265
# label 2
# index 5295
# label -1
# extraLabel 4266
# label -1
# extraLabel 4267
# label -1
# extraLabel 4268
# label -1
# extraLabel 4269
# label -1
# extraLabel 4270
# label -1
# extraLabel 4271
# label -1
# extraLabel 4272
# label -1
# extraLabel 4273
# label -1
# extraLabel 4274
# label -1
# extraLabel 4275
# label -1
# extraLabel 4276
# label -1
# extraLabel 4277
# label -1
# extraLabel 4278
# label -1
# extraLabel 4279
# label -1
# extraLabel 4280
# label -1
# extraLabel 4281
# label -1
# extraLabel 4282
# label -1
# extraLabel 4283
# label -1
# extraLabel 4284
# label -1
# extraLabel 4285
# label -1
# extraLabel 4286
# label 3
# index 5296
# label 3
# index 5297
# label 3
# index 5298
# label -1
# extraLabel 4287
# label 3
# index 5299
# label -1
# extraLabel 4288
# label 2
# index 5300
# label -1
# extraLabel 4289
# label -1
# extraLabel 4290
# label 0
# index 5301
# label -1
# extraLabel 4291
# label 0
# index 5302
# label 0
# index 5303
# label -1
# extraLabel 4292
# label -1
# extraLabel 4293
# label -1
# extraLabel 4294
# label -1
# extraLabel 4295
# label -1
# extraLabel 4296
# label 2
# index 5304
# label 2
# index 5305
# label 2
# index 5306
# label 2
# index 5307
# label 2
# index 5308
# label -1
# extraLabel 4297
# label -1
# extraLabel 4298
# label -1
# extraLabel 4299
# label -1
# extraLabel 4300
# label -1
# extraLabel 4301
# label -1
# extraLabel 4302
# label -1
# extraLabel 4303
# label -1
# extraLabel 4304
# label -1
# extraLabel 4305
# label -1
# extraLabel 4306
# label -1
# extraLabel 4307
# label -1
# extraLabel 4308
# label -1
# extraLabel 4309
# label 0
# index 5309
# label 0
# index 5310
# label -1
# extraLabel 4310
# label 0
# index 5311
# label -1
# extraLabel 4311
# label -1
# extraLabel 4312
# label -1
# extraLabel 4313
# label -1
# extraLabel 4314
# label -1
# extraLabel 4315
# label -1
# extraLabel 4316
# label -1
# extraLabel 4317
# label -1
# extraLabel 4318
# label 0
# index 5312
# label 0
# index 5313
# label 0
# index 5314
# label -1
# extraLabel 4319
# label 0
# index 5315
# label 0
# index 5316
# label -1
# extraLabel 4320
# label -1
# extraLabel 4321
# label -1
# extraLabel 4322
# label 0
# index 5317
# label 0
# index 5318
# label -1
# extraLabel 4323
# label -1
# extraLabel 4324
# label 3
# index 5319
# label -1
# extraLabel 4325
# label 3
# index 5320
# label 0
# index 5321
# label -1
# extraLabel 4326
# label -1
# extraLabel 4327
# label -1
# extraLabel 4328
# label -1
# extraLabel 4329
# label -1
# extraLabel 4330
# label -1
# extraLabel 4331
# label -1
# extraLabel 4332
# label -1
# extraLabel 4333
# label -1
# extraLabel 4334
# label 0
# index 5322
# label -1
# extraLabel 4335
# label 0
# index 5323
# label 3
# index 5324
# label 3
# index 5325
# label -1
# extraLabel 4336
# label 3
# index 5326
# label -1
# extraLabel 4337
# label -1
# extraLabel 4338
# label -1
# extraLabel 4339
# label -1
# extraLabel 4340
# label -1
# extraLabel 4341
# label -1
# extraLabel 4342
# label -1
# extraLabel 4343
# label -1
# extraLabel 4344
# label -1
# extraLabel 4345
# label -1
# extraLabel 4346
# label -1
# extraLabel 4347
# label 0
# index 5327
# label 0
# index 5328
# label 3
# index 5329
# label 1
# index 5330
# label -1
# extraLabel 4348
# label 3
# index 5331
# label -1
# extraLabel 4349
# label -1
# extraLabel 4350
# label 3
# index 5332
# label 3
# index 5333
# label -1
# extraLabel 4351
# label 1
# index 5334
# label 2
# index 5335
# label -1
# extraLabel 4352
# label 1
# index 5336
# label 1
# index 5337
# label -1
# extraLabel 4353
# label 1
# index 5338
# label 2
# index 5339
# label -1
# extraLabel 4354
# label -1
# extraLabel 4355
# label 2
# index 5340
# label 2
# index 5341
# label 2
# index 5342
# label 3
# index 5343
# label 2
# index 5344
# label 2
# index 5345
# label 2
# index 5346
# label -1
# extraLabel 4356
# label 1
# index 5347
# label -1
# extraLabel 4357
# label 1
# index 5348
# label -1
# extraLabel 4358
# label 3
# index 5349
# label -1
# extraLabel 4359
# label -1
# extraLabel 4360
# label -1
# extraLabel 4361
# label -1
# extraLabel 4362
# label -1
# extraLabel 4363
# label -1
# extraLabel 4364
# label 1
# index 5350
# label -1
# extraLabel 4365
# label -1
# extraLabel 4366
# label 1
# index 5351
# label -1
# extraLabel 4367
# label -1
# extraLabel 4368
# label 1
# index 5352
# label 1
# index 5353
# label -1
# extraLabel 4369
# label 2
# index 5354
# label 2
# index 5355
# label 2
# index 5356
# label 3
# index 5357
# label 2
# index 5358
# label -1
# extraLabel 4370
# label 2
# index 5359
# label 2
# index 5360
# label 2
# index 5361
# label -1
# extraLabel 4371
# label 2
# index 5362
# label 2
# index 5363
# label -1
# extraLabel 4372
# label -1
# extraLabel 4373
# label 2
# index 5364
# label -1
# extraLabel 4374
# label -1
# extraLabel 4375
# label 2
# index 5365
# label -1
# extraLabel 4376
# label -1
# extraLabel 4377
# label 2
# index 5366
# label 2
# index 5367
# label 1
# index 5368
# label 1
# index 5369
# label 2
# index 5370
# label 3
# index 5371
# label -1
# extraLabel 4378
# label -1
# extraLabel 4379
# label -1
# extraLabel 4380
# label -1
# extraLabel 4381
# label -1
# extraLabel 4382
# label -1
# extraLabel 4383
# label -1
# extraLabel 4384
# label -1
# extraLabel 4385
# label -1
# extraLabel 4386
# label -1
# extraLabel 4387
# label -1
# extraLabel 4388
# label -1
# extraLabel 4389
# label -1
# extraLabel 4390
# label -1
# extraLabel 4391
# label 2
# index 5372
# label -1
# extraLabel 4392
# label -1
# extraLabel 4393
# label -1
# extraLabel 4394
# label -1
# extraLabel 4395
# label 1
# index 5373
# label 1
# index 5374
# label 1
# index 5375
# label 1
# index 5376
# label -1
# extraLabel 4396
# label 1
# index 5377
# label 1
# index 5378
# label 1
# index 5379
# label 1
# index 5380
# label 1
# index 5381
# label 1
# index 5382
# label -1
# extraLabel 4397
# label -1
# extraLabel 4398
# label -1
# extraLabel 4399
# label -1
# extraLabel 4400
# label -1
# extraLabel 4401
# label -1
# extraLabel 4402
# label 1
# index 5383
# label 1
# index 5384
# label 1
# index 5385
# label 1
# index 5386
# label 1
# index 5387
# label -1
# extraLabel 4403
# label 1
# index 5388
# label -1
# extraLabel 4404
# label -1
# extraLabel 4405
# label -1
# extraLabel 4406
# label -1
# extraLabel 4407
# label 1
# index 5389
# label 1
# index 5390
# label 1
# index 5391
# label 1
# index 5392
# label 1
# index 5393
# label 1
# index 5394
# label 3
# index 5395
# label 3
# index 5396
# label -1
# extraLabel 4408
# label -1
# extraLabel 4409
# label -1
# extraLabel 4410
# label 0
# index 5397
# label -1
# extraLabel 4411
# label -1
# extraLabel 4412
# label -1
# extraLabel 4413
# label 0
# index 5398
# label 0
# index 5399
# label -1
# extraLabel 4414
# label 2
# index 5400
# label 2
# index 5401
# label 2
# index 5402
# label 2
# index 5403
# label 2
# index 5404
# label 2
# index 5405
# label 2
# index 5406
# label 2
# index 5407
# label -1
# extraLabel 4415
# label -1
# extraLabel 4416
# label 2
# index 5408
# label 2
# index 5409
# label -1
# extraLabel 4417
# label -1
# extraLabel 4418
# label 2
# index 5410
# label 2
# index 5411
# label 2
# index 5412
# label 2
# index 5413
# label 2
# index 5414
# label 2
# index 5415
# label 2
# index 5416
# label -1
# extraLabel 4419
# label 1
# index 5417
# label -1
# extraLabel 4420
# label -1
# extraLabel 4421
# label 1
# index 5418
# label 1
# index 5419
# label 1
# index 5420
# label 1
# index 5421
# label -1
# extraLabel 4422
# label -1
# extraLabel 4423
# label -1
# extraLabel 4424
# label 3
# index 5422
# label -1
# extraLabel 4425
# label -1
# extraLabel 4426
# label -1
# extraLabel 4427
# label -1
# extraLabel 4428
# label -1
# extraLabel 4429
# label -1
# extraLabel 4430
# label -1
# extraLabel 4431
# label -1
# extraLabel 4432
# label -1
# extraLabel 4433
# label -1
# extraLabel 4434
# label 3
# index 5423
# label -1
# extraLabel 4435
# label -1
# extraLabel 4436
# label -1
# extraLabel 4437
# label -1
# extraLabel 4438
# label -1
# extraLabel 4439
# label -1
# extraLabel 4440
# label -1
# extraLabel 4441
# label 0
# index 5424
# label 0
# index 5425
# label 0
# index 5426
# label -1
# extraLabel 4442
# label -1
# extraLabel 4443
# label 2
# index 5427
# label 2
# index 5428
# label 2
# index 5429
# label 2
# index 5430
# label -1
# extraLabel 4444
# label 1
# index 5431
# label 1
# index 5432
# label 1
# index 5433
# label 1
# index 5434
# label -1
# extraLabel 4445
# label -1
# extraLabel 4446
# label 1
# index 5435
# label -1
# extraLabel 4447
# label 1
# index 5436
# label 1
# index 5437
# label 1
# index 5438
# label 1
# index 5439
# label 1
# index 5440
# label -1
# extraLabel 4448
# label -1
# extraLabel 4449
# label -1
# extraLabel 4450
# label -1
# extraLabel 4451
# label -1
# extraLabel 4452
# label 3
# index 5441
# label 3
# index 5442
# label 3
# index 5443
# label -1
# extraLabel 4453
# label 3
# index 5444
# label -1
# extraLabel 4454
# label 3
# index 5445
# label -1
# extraLabel 4455
# label -1
# extraLabel 4456
# label 3
# index 5446
# label -1
# extraLabel 4457
# label -1
# extraLabel 4458
# label -1
# extraLabel 4459
# label 1
# index 5447
# label -1
# extraLabel 4460
# label 1
# index 5448
# label -1
# extraLabel 4461
# label -1
# extraLabel 4462
# label -1
# extraLabel 4463
# label -1
# extraLabel 4464
# label 3
# index 5449
# label -1
# extraLabel 4465
# label 1
# index 5450
# label -1
# extraLabel 4466
# label 3
# index 5451
# label 1
# index 5452
# label -1
# extraLabel 4467
# label 1
# index 5453
# label 1
# index 5454
# label 1
# index 5455
# label 1
# index 5456
# label 1
# index 5457
# label 1
# index 5458
# label 1
# index 5459
# label 1
# index 5460
# label 1
# index 5461
# label 1
# index 5462
# label 1
# index 5463
# label -1
# extraLabel 4468
# label 1
# index 5464
# label -1
# extraLabel 4469
# label 1
# index 5465
# label 1
# index 5466
# label 1
# index 5467
# label 1
# index 5468
# label 1
# index 5469
# label 1
# index 5470
# label 1
# index 5471
# label 1
# index 5472
# label 1
# index 5473
# label 1
# index 5474
# label 1
# index 5475
# label 1
# index 5476
# label 1
# index 5477
# label 1
# index 5478
# label -1
# extraLabel 4470
# label -1
# extraLabel 4471
# label 3
# index 5479
# label 3
# index 5480
# label -1
# extraLabel 4472
# label 3
# index 5481
# label 3
# index 5482
# label 3
# index 5483
# label -1
# extraLabel 4473
# label -1
# extraLabel 4474
# label 3
# index 5484
# label -1
# extraLabel 4475
# label -1
# extraLabel 4476
# label 3
# index 5485
# label -1
# extraLabel 4477
# label -1
# extraLabel 4478
# label 3
# index 5486
# label -1
# extraLabel 4479
# label 0
# index 5487
# label 0
# index 5488
# label -1
# extraLabel 4480
# label -1
# extraLabel 4481
# label -1
# extraLabel 4482
# label -1
# extraLabel 4483
# label 3
# index 5489
# label -1
# extraLabel 4484
# label -1
# extraLabel 4485
# label 3
# index 5490
# label -1
# extraLabel 4486
# label 0
# index 5491
# label -1
# extraLabel 4487
# label -1
# extraLabel 4488
# label -1
# extraLabel 4489
# label -1
# extraLabel 4490
# label -1
# extraLabel 4491
# label 0
# index 5492
# label 0
# index 5493
# label 0
# index 5494
# label 0
# index 5495
# label 0
# index 5496
# label 0
# index 5497
# label 0
# index 5498
# label 0
# index 5499
# label 0
# index 5500
# label 0
# index 5501
# label 0
# index 5502
# label -1
# extraLabel 4492
# label -1
# extraLabel 4493
# label -1
# extraLabel 4494
# label -1
# extraLabel 4495
# label -1
# extraLabel 4496
# label -1
# extraLabel 4497
# label -1
# extraLabel 4498
# label -1
# extraLabel 4499
# label 0
# index 5503
# label 0
# index 5504
# label 3
# index 5505
# label 3
# index 5506
# label -1
# extraLabel 4500
# label -1
# extraLabel 4501
# label -1
# extraLabel 4502
# label 0
# index 5507
# label -1
# extraLabel 4503
# label -1
# extraLabel 4504
# label -1
# extraLabel 4505
# label -1
# extraLabel 4506
# label 0
# index 5508
# label -1
# extraLabel 4507
# label -1
# extraLabel 4508
# label 0
# index 5509
# label 3
# index 5510
# label 0
# index 5511
# label 0
# index 5512
# label 0
# index 5513
# label 0
# index 5514
# label 0
# index 5515
# label 0
# index 5516
# label 0
# index 5517
# label 0
# index 5518
# label 0
# index 5519
# label 0
# index 5520
# label 0
# index 5521
# label 0
# index 5522
# label 0
# index 5523
# label 0
# index 5524
# label 0
# index 5525
# label 0
# index 5526
# label 0
# index 5527
# label 0
# index 5528
# label 0
# index 5529
# label 0
# index 5530
# label 0
# index 5531

# %%
class ModifiedAlexNet(nn.Module):
    def __init__(self, num_classes=4):
        super(ModifiedAlexNet, self).__init__()
        self.num_classes=num_classes
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(256, num_classes),
        )
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.features(x)
        #print('features',x.shape)
        x=torch.flatten(x, start_dim=2)#a1,a2,a3......al{a of dim c} 
        x=torch.sum(x, dim=2)#a1*alpha1+a2*alpha2+.......+al*alphal
        #print(x.shape)
        x=self.classifier(x)
        #print('classifier',x)
        #x=self.softmax(x)
        #print('softmax',x)
        #x = self.avgpool(x)
        #print('avgpool',x.shape)
        #x = torch.flatten(x, 1)
        #print('flatten',x.shape)
        #x = self.classifier(x)
        return x
def modifiedAlexNet(pretrained=False, progress=True, **kwargs):
    model_modified = ModifiedAlexNet(**kwargs)
    if pretrained:
        state_dict = load_state_dict_from_url(model_urls['alexnet'],
                                              progress=progress)
        model_modified.load_state_dict(state_dict)
    return model_modified

# %%
outputs_text= []
def hook_text(module, input, output):
    outputs_text.clear()
    outputs_text.append(output)
    return None
     

outputs_audio= []
def hook_audio(module, input, output):
    outputs_audio.clear()
    outputs_audio.append(output)
    return None

# %% [markdown]
# # new model

# %%
from transformers import BertModel, BertTokenizer

# %%
class CombinedAudioTextModel(nn.Module):
    def __init__(self, num_classes=4):
        super(CombinedAudioTextModel, self).__init__()
        self.num_classes=num_classes
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

        self.text_model=torch.load('/kaggle/input/emotion-recognition/model_text.pt')
        self.audio_model=torch.load('/kaggle/input/emotion-recognition/model_audio_new_opt.pt')

        self.text_model.bert.pooler.register_forward_hook(hook_text)
        self.audio_model.features.register_forward_hook(hook_audio)

        for param in self.text_model.parameters():
          param.requires_grad = False
        for param in self.audio_model.parameters():
          param.requires_grad = False

        self.dropout = nn.Dropout(.5)
        self.linear = nn.Linear(1024, num_classes)

        self.softmax = nn.Softmax(dim=1)

    def forward(self,text,audio):
        self.text_model(text)
        self.audio_model(audio)
        audio_embed=outputs_audio[0]
        text_embed=outputs_text[0]
        audio_embed=torch.flatten(audio_embed, start_dim=2)#a1,a2,a3......al{a of dim c} 
        audio_embed=torch.sum(audio_embed, dim=2)
        concat_embded=torch.cat((text_embed,audio_embed),1)
        x=self.dropout(concat_embded)
        x=self.linear(x)
        return x

# %%
model=CombinedAudioTextModel(num_classes=4)
model.to('cuda')
# Out:
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# CombinedAudioTextModel(
#   (text_model): BertForSequenceClassification(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#     (classifier): Linear(in_features=768, out_features=4, bias=True)
#   )
#   (audio_model): ModifiedAlexNet(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.5, inplace=False)
#       (1): Linear(in_features=256, out_features=4, bias=True)
#     )
#     (softmax): Softmax(dim=1)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear): Linear(in_features=1024, out_features=4, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %% [markdown]
# # check trainable model parameter

# %%
for name, param in model.named_parameters():
      if(param.requires_grad):
        print(name)
      else:
        print('no grad',name)
# Out:
# no grad text_model.bert.embeddings.word_embeddings.weight
# no grad text_model.bert.embeddings.position_embeddings.weight
# no grad text_model.bert.embeddings.token_type_embeddings.weight
# no grad text_model.bert.embeddings.LayerNorm.weight
# no grad text_model.bert.embeddings.LayerNorm.bias
# no grad text_model.bert.encoder.layer.0.attention.self.query.weight
# no grad text_model.bert.encoder.layer.0.attention.self.query.bias
# no grad text_model.bert.encoder.layer.0.attention.self.key.weight
# no grad text_model.bert.encoder.layer.0.attention.self.key.bias
# no grad text_model.bert.encoder.layer.0.attention.self.value.weight
# no grad text_model.bert.encoder.layer.0.attention.self.value.bias
# no grad text_model.bert.encoder.layer.0.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.0.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.0.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.0.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.0.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.0.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.0.output.dense.weight
# no grad text_model.bert.encoder.layer.0.output.dense.bias
# no grad text_model.bert.encoder.layer.0.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.0.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.1.attention.self.query.weight
# no grad text_model.bert.encoder.layer.1.attention.self.query.bias
# no grad text_model.bert.encoder.layer.1.attention.self.key.weight
# no grad text_model.bert.encoder.layer.1.attention.self.key.bias
# no grad text_model.bert.encoder.layer.1.attention.self.value.weight
# no grad text_model.bert.encoder.layer.1.attention.self.value.bias
# no grad text_model.bert.encoder.layer.1.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.1.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.1.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.1.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.1.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.1.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.1.output.dense.weight
# no grad text_model.bert.encoder.layer.1.output.dense.bias
# no grad text_model.bert.encoder.layer.1.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.1.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.2.attention.self.query.weight
# no grad text_model.bert.encoder.layer.2.attention.self.query.bias
# no grad text_model.bert.encoder.layer.2.attention.self.key.weight
# no grad text_model.bert.encoder.layer.2.attention.self.key.bias
# no grad text_model.bert.encoder.layer.2.attention.self.value.weight
# no grad text_model.bert.encoder.layer.2.attention.self.value.bias
# no grad text_model.bert.encoder.layer.2.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.2.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.2.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.2.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.2.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.2.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.2.output.dense.weight
# no grad text_model.bert.encoder.layer.2.output.dense.bias
# no grad text_model.bert.encoder.layer.2.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.2.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.3.attention.self.query.weight
# no grad text_model.bert.encoder.layer.3.attention.self.query.bias
# no grad text_model.bert.encoder.layer.3.attention.self.key.weight
# no grad text_model.bert.encoder.layer.3.attention.self.key.bias
# no grad text_model.bert.encoder.layer.3.attention.self.value.weight
# no grad text_model.bert.encoder.layer.3.attention.self.value.bias
# no grad text_model.bert.encoder.layer.3.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.3.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.3.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.3.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.3.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.3.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.3.output.dense.weight
# no grad text_model.bert.encoder.layer.3.output.dense.bias
# no grad text_model.bert.encoder.layer.3.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.3.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.4.attention.self.query.weight
# no grad text_model.bert.encoder.layer.4.attention.self.query.bias
# no grad text_model.bert.encoder.layer.4.attention.self.key.weight
# no grad text_model.bert.encoder.layer.4.attention.self.key.bias
# no grad text_model.bert.encoder.layer.4.attention.self.value.weight
# no grad text_model.bert.encoder.layer.4.attention.self.value.bias
# no grad text_model.bert.encoder.layer.4.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.4.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.4.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.4.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.4.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.4.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.4.output.dense.weight
# no grad text_model.bert.encoder.layer.4.output.dense.bias
# no grad text_model.bert.encoder.layer.4.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.4.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.5.attention.self.query.weight
# no grad text_model.bert.encoder.layer.5.attention.self.query.bias
# no grad text_model.bert.encoder.layer.5.attention.self.key.weight
# no grad text_model.bert.encoder.layer.5.attention.self.key.bias
# no grad text_model.bert.encoder.layer.5.attention.self.value.weight
# no grad text_model.bert.encoder.layer.5.attention.self.value.bias
# no grad text_model.bert.encoder.layer.5.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.5.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.5.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.5.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.5.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.5.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.5.output.dense.weight
# no grad text_model.bert.encoder.layer.5.output.dense.bias
# no grad text_model.bert.encoder.layer.5.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.5.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.6.attention.self.query.weight
# no grad text_model.bert.encoder.layer.6.attention.self.query.bias
# no grad text_model.bert.encoder.layer.6.attention.self.key.weight
# no grad text_model.bert.encoder.layer.6.attention.self.key.bias
# no grad text_model.bert.encoder.layer.6.attention.self.value.weight
# no grad text_model.bert.encoder.layer.6.attention.self.value.bias
# no grad text_model.bert.encoder.layer.6.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.6.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.6.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.6.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.6.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.6.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.6.output.dense.weight
# no grad text_model.bert.encoder.layer.6.output.dense.bias
# no grad text_model.bert.encoder.layer.6.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.6.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.7.attention.self.query.weight
# no grad text_model.bert.encoder.layer.7.attention.self.query.bias
# no grad text_model.bert.encoder.layer.7.attention.self.key.weight
# no grad text_model.bert.encoder.layer.7.attention.self.key.bias
# no grad text_model.bert.encoder.layer.7.attention.self.value.weight
# no grad text_model.bert.encoder.layer.7.attention.self.value.bias
# no grad text_model.bert.encoder.layer.7.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.7.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.7.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.7.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.7.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.7.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.7.output.dense.weight
# no grad text_model.bert.encoder.layer.7.output.dense.bias
# no grad text_model.bert.encoder.layer.7.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.7.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.8.attention.self.query.weight
# no grad text_model.bert.encoder.layer.8.attention.self.query.bias
# no grad text_model.bert.encoder.layer.8.attention.self.key.weight
# no grad text_model.bert.encoder.layer.8.attention.self.key.bias
# no grad text_model.bert.encoder.layer.8.attention.self.value.weight
# no grad text_model.bert.encoder.layer.8.attention.self.value.bias
# no grad text_model.bert.encoder.layer.8.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.8.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.8.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.8.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.8.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.8.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.8.output.dense.weight
# no grad text_model.bert.encoder.layer.8.output.dense.bias
# no grad text_model.bert.encoder.layer.8.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.8.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.9.attention.self.query.weight
# no grad text_model.bert.encoder.layer.9.attention.self.query.bias
# no grad text_model.bert.encoder.layer.9.attention.self.key.weight
# no grad text_model.bert.encoder.layer.9.attention.self.key.bias
# no grad text_model.bert.encoder.layer.9.attention.self.value.weight
# no grad text_model.bert.encoder.layer.9.attention.self.value.bias
# no grad text_model.bert.encoder.layer.9.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.9.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.9.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.9.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.9.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.9.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.9.output.dense.weight
# no grad text_model.bert.encoder.layer.9.output.dense.bias
# no grad text_model.bert.encoder.layer.9.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.9.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.10.attention.self.query.weight
# no grad text_model.bert.encoder.layer.10.attention.self.query.bias
# no grad text_model.bert.encoder.layer.10.attention.self.key.weight
# no grad text_model.bert.encoder.layer.10.attention.self.key.bias
# no grad text_model.bert.encoder.layer.10.attention.self.value.weight
# no grad text_model.bert.encoder.layer.10.attention.self.value.bias
# no grad text_model.bert.encoder.layer.10.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.10.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.10.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.10.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.10.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.10.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.10.output.dense.weight
# no grad text_model.bert.encoder.layer.10.output.dense.bias
# no grad text_model.bert.encoder.layer.10.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.10.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.11.attention.self.query.weight
# no grad text_model.bert.encoder.layer.11.attention.self.query.bias
# no grad text_model.bert.encoder.layer.11.attention.self.key.weight
# no grad text_model.bert.encoder.layer.11.attention.self.key.bias
# no grad text_model.bert.encoder.layer.11.attention.self.value.weight
# no grad text_model.bert.encoder.layer.11.attention.self.value.bias
# no grad text_model.bert.encoder.layer.11.attention.output.dense.weight
# no grad text_model.bert.encoder.layer.11.attention.output.dense.bias
# no grad text_model.bert.encoder.layer.11.attention.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.11.attention.output.LayerNorm.bias
# no grad text_model.bert.encoder.layer.11.intermediate.dense.weight
# no grad text_model.bert.encoder.layer.11.intermediate.dense.bias
# no grad text_model.bert.encoder.layer.11.output.dense.weight
# no grad text_model.bert.encoder.layer.11.output.dense.bias
# no grad text_model.bert.encoder.layer.11.output.LayerNorm.weight
# no grad text_model.bert.encoder.layer.11.output.LayerNorm.bias
# no grad text_model.bert.pooler.dense.weight
# no grad text_model.bert.pooler.dense.bias
# no grad text_model.classifier.weight
# no grad text_model.classifier.bias
# no grad audio_model.features.0.weight
# no grad audio_model.features.0.bias
# no grad audio_model.features.3.weight
# no grad audio_model.features.3.bias
# no grad audio_model.features.6.weight
# no grad audio_model.features.6.bias
# no grad audio_model.features.8.weight
# no grad audio_model.features.8.bias
# no grad audio_model.features.10.weight
# no grad audio_model.features.10.bias
# no grad audio_model.classifier.1.weight
# no grad audio_model.classifier.1.bias
# linear.weight
# linear.bias

# %% [markdown]
# # Train test split

# %%
import random
random.shuffle(docs)
random.shuffle(docs)
random.shuffle(docs)
total_length=len(docs)
train_length=int(.9*total_length)
train_list=docs[0:train_length]
test_list=docs[train_length:]
print('no of items for train ',len(train_list))
print('no of items for test ',len(test_list))
# Out:
# no of items for train  4977
# no of items for test  554

# %% [markdown]
# # test the model

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
label1=train_list[12]['label']
text=train_list[12]['text']
input_ids = torch.tensor(tokenizer.encode(text, add_special_tokens=True)).unsqueeze(0)  # Batch size 1
label1=torch.tensor([label1])
sprectrome=train_list[12]['sprectrome']
model.to('cpu')
model.eval()
with torch.no_grad():
    output = model(input_ids,sprectrome)
    #output.squeeze().shape
    #output=torch.flatten(output, start_dim=2)
    #print(output.shape)
    #output=torch.sum(output, dim=2)
    print(output)
# Out:
# tensor([[-4.6110,  1.3531,  2.8464,  1.3987]])

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./

# %% [markdown]
# # optimizer

# %%
import torch.optim as optim
optimizer = optim.Adam(params=model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
writer = SummaryWriter(log_dir='/kaggle/working/content/')

# %%
total_steps = 1
NUM_EPOCHS=2
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model.train()
model.to('cuda')
for epoch in range(NUM_EPOCHS):
  lr_scheduler.step()
  random.shuffle(train_list)
  for every_trainlist in train_list:
    label1=every_trainlist['label']
    text=every_trainlist['text']
    label1=torch.tensor([label1])
    sprectrome=every_trainlist['sprectrome']
    if(sprectrome.shape[2]>65):
      optimizer.zero_grad()
      input_ids = torch.tensor(tokenizer.encode(text, add_special_tokens=True)).unsqueeze(0) 
      sprectrome = sprectrome.to('cuda')
      label1=label1.to('cuda')
      input_ids=input_ids.to('cuda')
      output = model(input_ids,sprectrome)
      #print('softmax output ',output)
      loss = criterion(output, label1)
      #print('label1',label1)
      print('loss',loss.item())
      loss.backward()
      optimizer.step()
      _, preds = torch.max(output, 1)
      accuracy = torch.sum(preds == label1)
      print('accuracy.item()',accuracy.item())
      #print('preds',preds)
      if total_steps % 10 == 0:
        with torch.no_grad():
          _, preds = torch.max(output, 1)
          accuracy = torch.sum(preds == label1)
          #print('Epoch: {} \tStep: {} \tLoss: {:.4f} \tAcc: {}'.format(epoch + 1, total_steps, loss.item(), accuracy.item()))
          writer.add_scalar('loss', loss.item(), total_steps)
          writer.add_scalar('accuracy', accuracy.item(), total_steps)                     
      total_steps+=1
# Out:
# loss 3.9563186168670654
# accuracy.item() 0
# loss 1.7704745531082153
# accuracy.item() 0
# loss 1.454175591468811
# accuracy.item() 0
# loss 2.10772967338562
# accuracy.item() 0
# loss 1.1933374404907227
# accuracy.item() 0
# loss 1.5555663108825684
# accuracy.item() 0
# loss 0.779208779335022
# accuracy.item() 1
# loss 3.9043328762054443
# accuracy.item() 0
# loss 2.2218210697174072
# accuracy.item() 0
# loss 5.8310675621032715
# accuracy.item() 0
# loss 3.6508755683898926
# accuracy.item() 0
# loss 0.48990440368652344
# accuracy.item() 1
# loss 1.4755288362503052
# accuracy.item() 0
# loss 2.299358606338501
# accuracy.item() 0
# loss 3.2120954990386963
# accuracy.item() 0
# loss 0.33703023195266724
# accuracy.item() 1
# loss 0.5518983602523804
# accuracy.item() 1
# loss 1.9973037242889404
# accuracy.item() 0
# loss 1.23804771900177
# accuracy.item() 0
# loss 3.0980348587036133
# accuracy.item() 0
# loss 3.8754994869232178
# accuracy.item() 0
# loss 4.113394737243652
# accuracy.item() 0
# loss 0.177431121468544
# accuracy.item() 1
# loss 0.4305236339569092
# accuracy.item() 1
# loss 0.46116942167282104
# accuracy.item() 1
# loss 4.227960586547852
# accuracy.item() 0
# loss 1.9942502975463867
# accuracy.item() 0
# loss 0.357485830783844
# accuracy.item() 1
# loss 1.2250200510025024
# accuracy.item() 0
# loss 10.071962356567383
# accuracy.item() 0
# loss 0.8233092427253723
# accuracy.item() 0
# loss 2.854818344116211
# accuracy.item() 0
# loss 0.4297078549861908
# accuracy.item() 1
# loss 0.0848614051938057
# accuracy.item() 1
# loss 0.5704139471054077
# accuracy.item() 1
# loss 2.9709713459014893
# accuracy.item() 0
# loss 9.6526517868042
# accuracy.item() 0
# loss 2.6827733516693115
# accuracy.item() 0
# loss 0.6529910564422607
# accuracy.item() 1
# loss 3.9262335300445557
# accuracy.item() 0
# loss 0.07079954445362091
# accuracy.item() 1
# loss 3.517458438873291
# accuracy.item() 0
# loss 2.2213265895843506
# accuracy.item() 0
# loss 3.617133855819702
# accuracy.item() 0
# loss 0.4456515908241272
# accuracy.item() 1
# loss 0.8122131824493408
# accuracy.item() 0
# loss 0.5196793079376221
# accuracy.item() 1
# loss 1.49282968044281
# accuracy.item() 0
# loss 0.7513798475265503
# accuracy.item() 1
# loss 0.9455445408821106
# accuracy.item() 0
# loss 0.7375261783599854
# accuracy.item() 1
# loss 0.11314762383699417
# accuracy.item() 1
# loss 2.111262083053589
# accuracy.item() 0
# loss 0.12766046822071075
# accuracy.item() 1
# loss 1.188380479812622
# accuracy.item() 0
# loss 5.385457515716553
# accuracy.item() 0
# loss 0.3332262337207794
# accuracy.item() 1
# loss 1.2745980024337769
# accuracy.item() 0
# loss 0.03332136198878288
# accuracy.item() 1
# loss 0.08935032784938812
# accuracy.item() 1
# loss 2.928121566772461
# accuracy.item() 0
# loss 0.13410423696041107
# accuracy.item() 1
# loss 0.8445350527763367
# accuracy.item() 1
# loss 2.5930075645446777
# accuracy.item() 0
# loss 3.496171236038208
# accuracy.item() 0
# loss 0.7040431499481201
# accuracy.item() 1
# loss 0.020009800791740417
# accuracy.item() 1
# loss 0.7150169610977173
# accuracy.item() 0
# loss 0.22061100602149963
# accuracy.item() 1
# loss 1.6892979145050049
# accuracy.item() 0
# loss 0.29634830355644226
# accuracy.item() 1
# loss 0.41936153173446655
# accuracy.item() 1
# loss 0.9996768832206726
# accuracy.item() 0
# loss 1.4719403982162476
# accuracy.item() 0
# loss 0.8629336357116699
# accuracy.item() 1
# loss 7.039437770843506
# accuracy.item() 0
# loss 2.351003408432007
# accuracy.item() 0
# loss 0.4003089964389801
# accuracy.item() 1
# loss 0.832068145275116
# accuracy.item() 0
# loss 0.2437044233083725
# accuracy.item() 1
# loss 2.469698429107666
# accuracy.item() 0
# loss 0.15248741209506989
# accuracy.item() 1
# loss 0.6114962100982666
# accuracy.item() 1
# loss 0.18711838126182556
# accuracy.item() 1
# loss 0.9189947247505188
# accuracy.item() 0
# loss 0.4333348572254181
# accuracy.item() 1
# loss 1.3343563079833984
# accuracy.item() 0
# loss 0.3967818319797516
# accuracy.item() 1
# loss 5.227416515350342
# accuracy.item() 0
# loss 0.4265405833721161
# accuracy.item() 1
# loss 1.105882167816162
# accuracy.item() 0
# loss 0.08031703531742096
# accuracy.item() 1
# loss 0.06287914514541626
# accuracy.item() 1
# loss 1.2641401290893555
# accuracy.item() 0
# loss 1.241579532623291
# accuracy.item() 0
# loss 0.14541281759738922
# accuracy.item() 1
# loss 1.1578714847564697
# accuracy.item() 0
# loss 3.323214054107666
# accuracy.item() 0
# loss 0.007614397909492254
# accuracy.item() 1
# loss 0.43940702080726624
# accuracy.item() 1
# loss 0.2691672444343567
# accuracy.item() 1
# loss 0.42683303356170654
# accuracy.item() 1
# loss 0.7389584183692932
# accuracy.item() 1
# loss 0.6027811765670776
# accuracy.item() 1
# loss 1.2419513463974
# accuracy.item() 0
# loss 0.026449991390109062
# accuracy.item() 1
# loss 0.06969688087701797
# accuracy.item() 1
# loss 2.634874105453491
# accuracy.item() 0
# loss 0.44089630246162415
# accuracy.item() 1
# loss 0.1480061560869217
# accuracy.item() 1
# loss 0.17138174176216125
# accuracy.item() 1
# loss 0.005249881185591221
# accuracy.item() 1
# loss 0.178010955452919
# accuracy.item() 1
# loss 2.21475887298584
# accuracy.item() 0
# loss 0.22074313461780548
# accuracy.item() 1
# loss 3.3873441219329834
# accuracy.item() 0
# loss 0.029361076653003693
# accuracy.item() 1
# loss 0.020368576049804688
# accuracy.item() 1
# loss 0.23684576153755188
# accuracy.item() 1
# loss 0.14998768270015717
# accuracy.item() 1
# loss 0.7705537676811218
# accuracy.item() 1
# loss 1.2160067558288574
# accuracy.item() 0
# loss 0.04096808657050133
# accuracy.item() 1
# loss 0.41129884123802185
# accuracy.item() 1
# loss 0.017053045332431793
# accuracy.item() 1
# loss 0.848787784576416
# accuracy.item() 0
# loss 0.5224342942237854
# accuracy.item() 1
# loss 0.5763468742370605
# accuracy.item() 1
# loss 1.1084561347961426
# accuracy.item() 0
# loss 0.004401282407343388
# accuracy.item() 1
# loss 4.986265182495117
# accuracy.item() 0
# loss 0.031167037785053253
# accuracy.item() 1
# loss 0.13267971575260162
# accuracy.item() 1
# loss 0.8945834040641785
# accuracy.item() 0
# loss 1.5687119960784912
# accuracy.item() 0
# loss 0.3018920421600342
# accuracy.item() 1
# loss 0.028661292046308517
# accuracy.item() 1
# loss 0.12590599060058594
# accuracy.item() 1
# loss 0.7823988199234009
# accuracy.item() 1
# loss 0.06563734263181686
# accuracy.item() 1
# loss 0.8711009621620178
# accuracy.item() 1
# loss 0.09956179559230804
# accuracy.item() 1
# loss 0.5409162044525146
# accuracy.item() 1
# loss 0.6669121384620667
# accuracy.item() 1
# loss 0.7232719659805298
# accuracy.item() 1
# loss 0.4858011305332184
# accuracy.item() 1
# loss 0.06491613388061523
# accuracy.item() 1
# loss 0.19554626941680908
# accuracy.item() 1
# loss 0.031030908226966858
# accuracy.item() 1
# loss 0.5322017073631287
# accuracy.item() 1
# loss 0.5342454314231873
# accuracy.item() 1
# loss 0.2720744013786316
# accuracy.item() 1
# loss 0.36642464995384216
# accuracy.item() 1
# loss 0.4265400469303131
# accuracy.item() 1
# loss 1.6682689189910889
# accuracy.item() 0
# loss 2.299450635910034
# accuracy.item() 0
# loss 0.07372450083494186
# accuracy.item() 1
# loss 0.07745060324668884
# accuracy.item() 1
# loss 1.2523307800292969
# accuracy.item() 0
# loss 1.4305104514278355e-06
# accuracy.item() 1
# loss 0.19948874413967133
# accuracy.item() 1
# loss 0.16844335198402405
# accuracy.item() 1
# loss 0.11101281642913818
# accuracy.item() 1
# loss 0.3867706060409546
# accuracy.item() 1
# loss 0.49988412857055664
# accuracy.item() 1
# loss 0.08754769712686539
# accuracy.item() 1
# loss 1.0789189338684082
# accuracy.item() 0
# loss 0.05353732779622078
# accuracy.item() 1
# loss 2.4949350357055664
# accuracy.item() 0
# loss 0.5155846476554871
# accuracy.item() 1
# loss 0.08303013443946838
# accuracy.item() 1
# loss 0.006783551536500454
# accuracy.item() 1
# loss 0.0443631187081337
# accuracy.item() 1
# loss 0.13840419054031372
# accuracy.item() 1
# loss 0.6777164936065674
# accuracy.item() 1
# loss 0.06645429134368896
# accuracy.item() 1
# loss 0.010983013547956944
# accuracy.item() 1
# loss 0.009727340191602707
# accuracy.item() 1
# loss 0.6079235076904297
# accuracy.item() 1
# loss 0.01819608360528946
# accuracy.item() 1
# loss 2.6431524753570557
# accuracy.item() 0
# loss 0.2153910994529724
# accuracy.item() 1
# loss 0.0001915509783430025
# accuracy.item() 1
# loss 0.12159416824579239
# accuracy.item() 1
# loss 0.2696203291416168
# accuracy.item() 1
# loss 0.047506943345069885
# accuracy.item() 1
# loss 0.30523455142974854
# accuracy.item() 1
# loss 3.5758137702941895
# accuracy.item() 0
# loss 0.13253365457057953
# accuracy.item() 1
# loss 0.19781263172626495
# accuracy.item() 1
# loss 0.026382189244031906
# accuracy.item() 1
# loss 0.22314907610416412
# accuracy.item() 1
# loss 0.017967088147997856
# accuracy.item() 1
# loss 0.16177140176296234
# accuracy.item() 1
# loss 0.09571174532175064
# accuracy.item() 1
# loss 2.6566314697265625
# accuracy.item() 0
# loss 0.0013303249143064022
# accuracy.item() 1
# loss 1.7686455249786377
# accuracy.item() 0
# loss 0.011613147333264351
# accuracy.item() 1
# loss 0.7066798806190491
# accuracy.item() 1
# loss 0.38535404205322266
# accuracy.item() 1
# loss 0.41928690671920776
# accuracy.item() 1
# loss 0.16142991185188293
# accuracy.item() 1
# loss 0.18802377581596375
# accuracy.item() 1
# loss 0.35514146089553833
# accuracy.item() 1
# loss 0.04591190069913864
# accuracy.item() 1
# loss 0.12105260044336319
# accuracy.item() 1
# loss 0.03172072023153305
# accuracy.item() 1
# loss 3.3306472301483154
# accuracy.item() 0
# loss 0.36729007959365845
# accuracy.item() 1
# loss 1.9129353761672974
# accuracy.item() 0
# loss 0.15121778845787048
# accuracy.item() 1
# loss 1.2521824836730957
# accuracy.item() 0
# loss 0.1601254791021347
# accuracy.item() 1
# loss 0.6099567413330078
# accuracy.item() 1
# loss 1.8217512369155884
# accuracy.item() 0
# loss 0.8162896633148193
# accuracy.item() 1
# loss 9.744548797607422
# accuracy.item() 0
# loss 0.6666589379310608
# accuracy.item() 1
# loss 0.3870028257369995
# accuracy.item() 1
# loss 0.003184487810358405
# accuracy.item() 1
# loss 0.005015885457396507
# accuracy.item() 1
# loss 0.029743820428848267
# accuracy.item() 1
# loss 1.3310503959655762
# accuracy.item() 0
# loss 0.10114555805921555
# accuracy.item() 1
# loss 1.490105023549404e-05
# accuracy.item() 1
# loss 0.30386409163475037
# accuracy.item() 1
# loss 0.018814552575349808
# accuracy.item() 1
# loss 0.20741379261016846
# accuracy.item() 1
# loss 0.11587386578321457
# accuracy.item() 1
# loss 0.07519444823265076
# accuracy.item() 1
# loss 0.17214253544807434
# accuracy.item() 1
# loss 1.9073468138230965e-06
# accuracy.item() 1
# loss 0.003988289274275303
# accuracy.item() 1
# loss 0.029682952910661697
# accuracy.item() 1
# loss 0.1871439814567566
# accuracy.item() 1
# loss 0.29755398631095886
# accuracy.item() 1
# loss 0.022593233734369278
# accuracy.item() 1
# loss 0.0297715924680233
# accuracy.item() 1
# loss 0.16059909760951996
# accuracy.item() 1
# loss 0.08820299804210663
# accuracy.item() 1
# loss 0.14516334235668182
# accuracy.item() 1
# loss 0.012080127373337746
# accuracy.item() 1
# loss 0.3432353734970093
# accuracy.item() 1
# loss 0.19029542803764343
# accuracy.item() 1
# loss 0.3325932025909424
# accuracy.item() 1
# loss 0.09456942230463028
# accuracy.item() 1
# loss 1.2681074142456055
# accuracy.item() 0
# loss 0.03910638764500618
# accuracy.item() 1
# loss 0.352966845035553
# accuracy.item() 1
# loss 0.0482337661087513
# accuracy.item() 1
# loss 0.6893108487129211
# accuracy.item() 1
# loss 0.06109214946627617
# accuracy.item() 1
# loss 0.01029608678072691
# accuracy.item() 1
# loss 0.08838481456041336
# accuracy.item() 1
# loss 0.11890561878681183
# accuracy.item() 1
# loss 0.28253260254859924
# accuracy.item() 1
# loss 0.35816213488578796
# accuracy.item() 1
# loss 0.16217541694641113
# accuracy.item() 1
# loss 2.0590832233428955
# accuracy.item() 0
# loss 0.13196340203285217
# accuracy.item() 1
# loss 0.1374986320734024
# accuracy.item() 1
# loss 2.09812068939209
# accuracy.item() 0
# loss 0.01524663157761097
# accuracy.item() 1
# loss 2.365870714187622
# accuracy.item() 0
# loss 0.056809160858392715
# accuracy.item() 1
# loss 0.007833356969058514
# accuracy.item() 1
# loss 0.04337039589881897
# accuracy.item() 1
# loss 0.006180933676660061
# accuracy.item() 1
# loss 1.0758793354034424
# accuracy.item() 0
# loss 0.020564556121826172
# accuracy.item() 1
# loss 0.21544530987739563
# accuracy.item() 1
# loss 4.632719039916992
# accuracy.item() 0
# loss 0.06661389768123627
# accuracy.item() 1
# loss 0.08855351060628891
# accuracy.item() 1
# loss 0.15602357685565948
# accuracy.item() 1
# loss 0.062291376292705536
# accuracy.item() 1
# loss 0.39779213070869446
# accuracy.item() 1
# loss 0.00982685573399067
# accuracy.item() 1
# loss 0.07230529189109802
# accuracy.item() 1
# loss 0.014644747599959373
# accuracy.item() 1
# loss 0.4045238792896271
# accuracy.item() 1
# loss 1.4608864784240723
# accuracy.item() 0
# loss 0.000645429186988622
# accuracy.item() 1
# loss 1.6251411437988281
# accuracy.item() 0
# loss 0.028345923870801926
# accuracy.item() 1
# loss 2.610649426060263e-05
# accuracy.item() 1
# loss 0.005375573877245188
# accuracy.item() 1
# loss 0.004628302529454231
# accuracy.item() 1
# loss 0.10623490065336227
# accuracy.item() 1
# loss 1.3758982419967651
# accuracy.item() 0
# loss 0.0065309652127325535
# accuracy.item() 1
# loss 0.04374656081199646
# accuracy.item() 1
# loss 0.40257176756858826
# accuracy.item() 1
# loss 0.016027191653847694
# accuracy.item() 1
# loss 0.0007296522380784154
# accuracy.item() 1
# loss 0.14786899089813232
# accuracy.item() 1
# loss 2.0166773796081543
# accuracy.item() 0
# loss 0.07396167516708374
# accuracy.item() 1
# loss 0.1359148472547531
# accuracy.item() 1
# loss 0.016639500856399536
# accuracy.item() 1
# loss 0.012042791582643986
# accuracy.item() 1
# loss 0.015989767387509346
# accuracy.item() 1
# loss 1.0048511028289795
# accuracy.item() 0
# loss 0.07940585166215897
# accuracy.item() 1
# loss 0.2560441792011261
# accuracy.item() 1
# loss 1.105971097946167
# accuracy.item() 0
# loss 0.0875023677945137
# accuracy.item() 1
# loss 0.20807817578315735
# accuracy.item() 1
# loss 0.03402826189994812
# accuracy.item() 1
# loss 0.0010594476480036974
# accuracy.item() 1
# loss 0.0831400603055954
# accuracy.item() 1
# loss 0.03162335976958275
# accuracy.item() 1
# loss 0.3178609609603882
# accuracy.item() 1
# loss 0.03603949770331383
# accuracy.item() 1
# loss 0.022499993443489075
# accuracy.item() 1
# loss 0.007814549840986729
# accuracy.item() 1
# loss 0.677344560623169
# accuracy.item() 1
# loss 0.07501220703125
# accuracy.item() 1
# loss 0.0884065330028534
# accuracy.item() 1
# loss 0.2762433886528015
# accuracy.item() 1
# loss 0.012301172129809856
# accuracy.item() 1
# loss 0.02822459302842617
# accuracy.item() 1
# loss 0.3824257552623749
# accuracy.item() 1
# loss 0.028538841754198074
# accuracy.item() 1
# loss 0.05412213131785393
# accuracy.item() 1
# loss 0.05501748248934746
# accuracy.item() 1
# loss 2.526201009750366
# accuracy.item() 0
# loss 2.265350103378296
# accuracy.item() 0
# loss 0.0774952843785286
# accuracy.item() 1
# loss 0.012111220508813858
# accuracy.item() 1
# loss 0.001988697098568082
# accuracy.item() 1
# loss 1.1509051322937012
# accuracy.item() 0
# loss 6.48477507638745e-05
# accuracy.item() 1
# loss 1.6001478433609009
# accuracy.item() 0
# loss 0.031179286539554596
# accuracy.item() 1
# loss 0.02045559138059616
# accuracy.item() 1
# loss 0.13692860305309296
# accuracy.item() 1
# loss 0.006504199001938105
# accuracy.item() 1
# loss 0.030234798789024353
# accuracy.item() 1
# loss 0.04386340081691742
# accuracy.item() 1
# loss 0.00949143711477518
# accuracy.item() 1
# loss 2.294363260269165
# accuracy.item() 0
# loss 0.04948991537094116
# accuracy.item() 1
# loss 0.000985375139862299
# accuracy.item() 1
# loss 5.6622808187967166e-05
# accuracy.item() 1
# loss 0.1711108386516571
# accuracy.item() 1
# loss 0.1568862348794937
# accuracy.item() 1
# loss 0.11857247352600098
# accuracy.item() 1
# loss 0.015657585114240646
# accuracy.item() 1
# loss 0.20269881188869476
# accuracy.item() 1
# loss 0.005825090687721968
# accuracy.item() 1
# loss 0.010398848913609982
# accuracy.item() 1
# loss 0.05769592151045799
# accuracy.item() 1
# loss 0.11969311535358429
# accuracy.item() 1
# loss 0.29322728514671326
# accuracy.item() 1
# loss 0.017452478408813477
# accuracy.item() 1
# loss 0.009834292344748974
# accuracy.item() 1
# loss 0.044081296771764755
# accuracy.item() 1
# loss 0.0028174726758152246
# accuracy.item() 1
# loss 0.13677963614463806
# accuracy.item() 1
# loss 0.05373459681868553
# accuracy.item() 1
# loss 5.082401752471924
# accuracy.item() 0
# loss 0.10745789110660553
# accuracy.item() 1
# loss 0.04907992482185364
# accuracy.item() 1
# loss 0.010262695141136646
# accuracy.item() 1
# loss 1.441653847694397
# accuracy.item() 0
# loss 0.03234346583485603
# accuracy.item() 1
# loss 0.019650429487228394
# accuracy.item() 1
# loss 0.22681483626365662
# accuracy.item() 1
# loss 0.39653342962265015
# accuracy.item() 1
# loss 0.08821795135736465
# accuracy.item() 1
# loss 0.04497120529413223
# accuracy.item() 1
# loss 0.017097460106015205
# accuracy.item() 1
# loss 0.011810733005404472
# accuracy.item() 1
# loss 0.03915247321128845
# accuracy.item() 1
# loss 8.40390202938579e-05
# accuracy.item() 1
# loss 0.003631902625784278
# accuracy.item() 1
# loss 0.25709351897239685
# accuracy.item() 1
# loss 0.02142639271914959
# accuracy.item() 1
# loss 0.3053983747959137
# accuracy.item() 1
# loss 0.001312943291850388
# accuracy.item() 1
# loss 0.07014507055282593
# accuracy.item() 1
# loss 0.0023707635700702667
# accuracy.item() 1
# loss 0.05584022402763367
# accuracy.item() 1
# loss 0.00982921663671732
# accuracy.item() 1
# loss 0.00344635546207428
# accuracy.item() 1
# loss 0.005473745055496693
# accuracy.item() 1
# loss 0.009282644838094711
# accuracy.item() 1
# loss 0.6873835921287537
# accuracy.item() 1
# loss 0.08812146633863449
# accuracy.item() 1
# loss 0.052192799746990204
# accuracy.item() 1
# loss 0.00025507534155622125
# accuracy.item() 1
# loss 0.007046372629702091
# accuracy.item() 1
# loss 0.14372797310352325
# accuracy.item() 1
# loss 0.05738316476345062
# accuracy.item() 1
# loss 5.960462772236497e-07
# accuracy.item() 1
# loss 5.3165931603871286e-05
# accuracy.item() 1
# loss 0.27338096499443054
# accuracy.item() 1
# loss 1.5127050876617432
# accuracy.item() 0
# loss 0.0003953390696551651
# accuracy.item() 1
# loss 0.0026265429332852364
# accuracy.item() 1
# loss 0.3150113821029663
# accuracy.item() 1
# loss 0.038937054574489594
# accuracy.item() 1
# loss 0.17331081628799438
# accuracy.item() 1
# loss 1.5627000331878662
# accuracy.item() 0
# loss 2.143018960952759
# accuracy.item() 0
# loss 0.9328460097312927
# accuracy.item() 0
# loss 1.5497195136049413e-06
# accuracy.item() 1
# loss 0.006387650966644287
# accuracy.item() 1
# loss 0.003932719584554434
# accuracy.item() 1
# loss 0.029922006651759148
# accuracy.item() 1
# loss 0.07391716539859772
# accuracy.item() 1
# loss 0.02871469408273697
# accuracy.item() 1
# loss 0.11927251517772675
# accuracy.item() 1
# loss 0.0009484559996053576
# accuracy.item() 1
# loss 0.014028864912688732
# accuracy.item() 1
# loss 0.00431784288957715
# accuracy.item() 1
# loss 0.009315832518041134
# accuracy.item() 1
# loss 0.0633363351225853
# accuracy.item() 1
# loss 0.013180391862988472
# accuracy.item() 1
# loss 0.046646598726511
# accuracy.item() 1
# loss 0.0047149197198450565
# accuracy.item() 1
# loss 0.016883568838238716
# accuracy.item() 1
# loss 0.06664903461933136
# accuracy.item() 1
# loss 0.04640137776732445
# accuracy.item() 1
# loss 0.041203200817108154
# accuracy.item() 1
# loss 0.022693809121847153
# accuracy.item() 1
# loss 0.21535265445709229
# accuracy.item() 1
# loss 2.191007614135742
# accuracy.item() 0
# loss 0.026102684438228607
# accuracy.item() 1
# loss 0.13582555949687958
# accuracy.item() 1
# loss 0.363986611366272
# accuracy.item() 1
# loss 0.005129510071128607
# accuracy.item() 1
# loss 0.18165698647499084
# accuracy.item() 1
# loss 0.05251634865999222
# accuracy.item() 1
# loss 1.7069445848464966
# accuracy.item() 0
# loss 2.565796375274658
# accuracy.item() 0
# loss 0.00903954915702343
# accuracy.item() 1
# loss 0.013944579288363457
# accuracy.item() 1
# loss 0.14886455237865448
# accuracy.item() 1
# loss 0.007077859248965979
# accuracy.item() 1
# loss 0.0017408467829227448
# accuracy.item() 1
# loss 0.17550557851791382
# accuracy.item() 1
# loss 0.0041862004436552525
# accuracy.item() 1
# loss 0.32773229479789734
# accuracy.item() 1
# loss 0.0785486176609993
# accuracy.item() 1
# loss 0.00701890978962183
# accuracy.item() 1
# loss 2.7179348762729205e-05
# accuracy.item() 1
# loss 4.426962375640869
# accuracy.item() 0
# loss 0.014566035009920597
# accuracy.item() 1
# loss 0.001629216712899506
# accuracy.item() 1
# loss 0.076619952917099
# accuracy.item() 1
# loss 0.00027414379292167723
# accuracy.item() 1
# loss 0.0009109399979934096
# accuracy.item() 1
# loss 0.01686692424118519
# accuracy.item() 1
# loss 0.0006270825979299843
# accuracy.item() 1
# loss 0.01134233083575964
# accuracy.item() 1
# loss 0.0025228597223758698
# accuracy.item() 1
# loss 0.03905090317130089
# accuracy.item() 1
# loss 0.00011884459672728553
# accuracy.item() 1
# loss 0.15575011074543
# accuracy.item() 1
# loss 0.021234432235360146
# accuracy.item() 1
# loss 0.8015807867050171
# accuracy.item() 1
# loss 0.01173804234713316
# accuracy.item() 1
# loss 0.011172590777277946
# accuracy.item() 1
# loss 0.002401922130957246
# accuracy.item() 1
# loss 0.1783844232559204
# accuracy.item() 1
# loss 0.7265114188194275
# accuracy.item() 1
# loss 0.050053391605615616
# accuracy.item() 1
# loss 0.8170524835586548
# accuracy.item() 0
# loss 0.012202726677060127
# accuracy.item() 1
# loss 0.004041718319058418
# accuracy.item() 1
# loss 0.013728718273341656
# accuracy.item() 1
# loss 0.06815290451049805
# accuracy.item() 1
# loss 0.06304749846458435
# accuracy.item() 1
# loss 0.010265291668474674
# accuracy.item() 1
# loss 0.058160774409770966
# accuracy.item() 1
# loss 1.126583456993103
# accuracy.item() 0
# loss 0.001967162825167179
# accuracy.item() 1
# loss 7.1403817855753e-05
# accuracy.item() 1
# loss 0.025742707774043083
# accuracy.item() 1
# loss 0.003159176791086793
# accuracy.item() 1
# loss 0.010240158997476101
# accuracy.item() 1
# loss 0.006907038856297731
# accuracy.item() 1
# loss 0.06934091448783875
# accuracy.item() 1
# loss 0.9850109219551086
# accuracy.item() 0
# loss 0.09320253133773804
# accuracy.item() 1
# loss 0.008747000247240067
# accuracy.item() 1
# loss 0.0022631289903074503
# accuracy.item() 1
# loss 0.0014367506373673677
# accuracy.item() 1
# loss 0.007133727427572012
# accuracy.item() 1
# loss 0.1870671659708023
# accuracy.item() 1
# loss 0.01877536252140999
# accuracy.item() 1
# loss 2.407998726994265e-05
# accuracy.item() 1
# loss 0.0025798154529184103
# accuracy.item() 1
# loss 0.03164403513073921
# accuracy.item() 1
# loss 0.017817558720707893
# accuracy.item() 1
# loss 0.056298159062862396
# accuracy.item() 1
# loss 5.766022682189941
# accuracy.item() 0
# loss 0.006945632863789797
# accuracy.item() 1
# loss 0.036535896360874176
# accuracy.item() 1
# loss 0.03593830019235611
# accuracy.item() 1
# loss 0.08187728375196457
# accuracy.item() 1
# loss 0.04133646562695503
# accuracy.item() 1
# loss 0.41061708331108093
# accuracy.item() 1
# loss 0.00010573305189609528
# accuracy.item() 1
# loss 0.1520666778087616
# accuracy.item() 1
# loss 0.054103609174489975
# accuracy.item() 1
# loss 5.181181907653809
# accuracy.item() 0
# loss 0.003725732211023569
# accuracy.item() 1
# loss 0.020637191832065582
# accuracy.item() 1
# loss 0.001561851822771132
# accuracy.item() 1
# loss 0.0010720703285187483
# accuracy.item() 1
# loss 0.4356614649295807
# accuracy.item() 1
# loss 4.649054244509898e-05
# accuracy.item() 1
# loss 1.6548247337341309
# accuracy.item() 0
# loss 0.22212593257427216
# accuracy.item() 1
# loss 0.08761224150657654
# accuracy.item() 1
# loss 0.04894201457500458
# accuracy.item() 1
# loss 0.0054294029250741005
# accuracy.item() 1
# loss 0.00880301184952259
# accuracy.item() 1
# loss 0.24310770630836487
# accuracy.item() 1
# loss 0.04769665375351906
# accuracy.item() 1
# loss 0.06417171657085419
# accuracy.item() 1
# loss 0.0734444111585617
# accuracy.item() 1
# loss 0.297928124666214
# accuracy.item() 1
# loss 0.3283926248550415
# accuracy.item() 1
# loss 0.013282152824103832
# accuracy.item() 1
# loss 6.6756979322235566e-06
# accuracy.item() 1
# loss 0.109990693628788
# accuracy.item() 1
# loss 0.1731027066707611
# accuracy.item() 1
# loss 0.008466659113764763
# accuracy.item() 1
# loss 0.23527167737483978
# accuracy.item() 1
# loss 0.05158569663763046
# accuracy.item() 1
# loss 0.21624284982681274
# accuracy.item() 1
# loss 0.15908963978290558
# accuracy.item() 1
# loss 5.413966178894043
# accuracy.item() 0
# loss 0.048381999135017395
# accuracy.item() 1
# loss 0.01766648329794407
# accuracy.item() 1
# loss 0.06595668196678162
# accuracy.item() 1
# loss 0.005354705266654491
# accuracy.item() 1
# loss 0.003812071168795228
# accuracy.item() 1
# loss 2.9745113849639893
# accuracy.item() 0
# loss 2.1959266662597656
# accuracy.item() 0
# loss 0.07143805921077728
# accuracy.item() 1
# loss 0.00566199840977788
# accuracy.item() 1
# loss 0.010391770862042904
# accuracy.item() 1
# loss 0.00027640812913887203
# accuracy.item() 1
# loss 0.005603320896625519
# accuracy.item() 1
# loss 0.015361213125288486
# accuracy.item() 1
# loss 0.020613370463252068
# accuracy.item() 1
# loss 0.008537224493920803
# accuracy.item() 1
# loss 2.777890920639038
# accuracy.item() 0
# loss 0.0019182630348950624
# accuracy.item() 1
# loss 0.18871280550956726
# accuracy.item() 1
# loss 0.1206747367978096
# accuracy.item() 1
# loss 0.0018944665789604187
# accuracy.item() 1
# loss 0.0155266048386693
# accuracy.item() 1
# loss 7.509902934543788e-05
# accuracy.item() 1
# loss 0.03049476630985737
# accuracy.item() 1
# loss 0.062193140387535095
# accuracy.item() 1
# loss 0.007849442772567272
# accuracy.item() 1
# loss 0.012195543386042118
# accuracy.item() 1
# loss 1.9208683967590332
# accuracy.item() 0
# loss 0.14265213906764984
# accuracy.item() 1
# loss 1.1973145008087158
# accuracy.item() 0
# loss 3.4570634852570947e-06
# accuracy.item() 1
# loss 0.013059794902801514
# accuracy.item() 1
# loss 0.056895654648542404
# accuracy.item() 1
# loss 0.12418991327285767
# accuracy.item() 1
# loss 0.07647828012704849
# accuracy.item() 1
# loss 0.017478367313742638
# accuracy.item() 1
# loss 0.029782122001051903
# accuracy.item() 1
# loss 0.028237340971827507
# accuracy.item() 1
# loss 0.023453790694475174
# accuracy.item() 1
# loss 0.114518903195858
# accuracy.item() 1
# loss 0.02297182008624077
# accuracy.item() 1
# loss 0.04562162980437279
# accuracy.item() 1
# loss 0.04750819504261017
# accuracy.item() 1
# loss 0.03417216241359711
# accuracy.item() 1
# loss 0.001904699020087719
# accuracy.item() 1
# loss 1.5023409128189087
# accuracy.item() 0
# loss 0.05380226671695709
# accuracy.item() 1
# loss 0.0291588231921196
# accuracy.item() 1
# loss 0.49871373176574707
# accuracy.item() 1
# loss 0.1054176390171051
# accuracy.item() 1
# loss 0.23539575934410095
# accuracy.item() 1
# loss 0.03275056928396225
# accuracy.item() 1
# loss 0.18407243490219116
# accuracy.item() 1
# loss 0.017887817695736885
# accuracy.item() 1
# loss 0.00042250767000950873
# accuracy.item() 1
# loss 0.0031392124947160482
# accuracy.item() 1
# loss 0.34195542335510254
# accuracy.item() 1
# loss 0.026715006679296494
# accuracy.item() 1
# loss 0.004755022004246712
# accuracy.item() 1
# loss 0.06604138016700745
# accuracy.item() 1
# loss 0.011474919505417347
# accuracy.item() 1
# loss 0.8004311919212341
# accuracy.item() 0
# loss 0.3692270815372467
# accuracy.item() 1
# loss 0.09723163396120071
# accuracy.item() 1
# loss 0.37412896752357483
# accuracy.item() 1
# loss 0.03702343627810478
# accuracy.item() 1
# loss 0.0035394898150116205
# accuracy.item() 1
# loss 0.07004682719707489
# accuracy.item() 1
# loss 0.03152599185705185
# accuracy.item() 1
# loss 1.8832029104232788
# accuracy.item() 0
# loss 0.04650004208087921
# accuracy.item() 1
# loss 0.1767221838235855
# accuracy.item() 1
# loss 0.0075881341472268105
# accuracy.item() 1
# loss 0.03203364089131355
# accuracy.item() 1
# loss 0.1284182369709015
# accuracy.item() 1
# loss 0.09245692193508148
# accuracy.item() 1
# loss 0.030502166599035263
# accuracy.item() 1
# loss 0.21632657945156097
# accuracy.item() 1
# loss 0.00912861991673708
# accuracy.item() 1
# loss 0.10760487616062164
# accuracy.item() 1
# loss 0.0001134808044298552
# accuracy.item() 1
# loss 3.576278118089249e-07
# accuracy.item() 1
# loss 9.274052717955783e-05
# accuracy.item() 1
# loss 0.0035535066854208708
# accuracy.item() 1
# loss 0.039980459958314896
# accuracy.item() 1
# loss 0.06651173532009125
# accuracy.item() 1
# loss 0.008551998995244503
# accuracy.item() 1
# loss 0.020963873714208603
# accuracy.item() 1
# loss 1.0648587942123413
# accuracy.item() 0
# loss 0.038039691746234894
# accuracy.item() 1
# loss 0.11433178186416626
# accuracy.item() 1
# loss 1.168244216387393e-05
# accuracy.item() 1
# loss 0.03208882734179497
# accuracy.item() 1
# loss 0.03711361065506935
# accuracy.item() 1
# loss 0.011057528667151928
# accuracy.item() 1
# loss 2.322134256362915
# accuracy.item() 0
# loss 0.027689145877957344
# accuracy.item() 1
# loss 0.06869394332170486
# accuracy.item() 1
# loss 0.041737981140613556
# accuracy.item() 1
# loss 0.8618241548538208
# accuracy.item() 0
# loss 0.0005474975914694369
# accuracy.item() 1
# loss 0.05462973192334175
# accuracy.item() 1
# loss 0.02340022288262844
# accuracy.item() 1
# loss 0.04760197550058365
# accuracy.item() 1
# loss 0.03189855441451073
# accuracy.item() 1
# loss 0.1795695424079895
# accuracy.item() 1
# loss 0.01130308024585247
# accuracy.item() 1
# loss 0.051905591040849686
# accuracy.item() 1
# loss 0.28832998871803284
# accuracy.item() 1
# loss 0.02148006483912468
# accuracy.item() 1
# loss 0.17844296991825104
# accuracy.item() 1
# loss 7.629365427419543e-06
# accuracy.item() 1
# loss 0.02067432552576065
# accuracy.item() 1
# loss 1.7881233361549675e-05
# accuracy.item() 1
# loss 0.006869390141218901
# accuracy.item() 1
# loss 0.001069450518116355
# accuracy.item() 1
# loss 0.00454381387680769
# accuracy.item() 1
# loss 0.0007251255447044969
# accuracy.item() 1
# loss 0.017447207123041153
# accuracy.item() 1
# loss 0.0778365507721901
# accuracy.item() 1
# loss 0.06960137188434601
# accuracy.item() 1
# loss 0.17752046883106232
# accuracy.item() 1
# loss 0.023281902074813843
# accuracy.item() 1
# loss 2.0169711112976074
# accuracy.item() 0
# loss 5.876845170860179e-05
# accuracy.item() 1
# loss 0.00040618274942971766
# accuracy.item() 1
# loss 0.4170800745487213
# accuracy.item() 1
# loss 0.006340980529785156
# accuracy.item() 1
# loss 0.16310730576515198
# accuracy.item() 1
# loss 0.03055315650999546
# accuracy.item() 1
# loss 0.01736566796898842
# accuracy.item() 1
# loss 0.6114628314971924
# accuracy.item() 1
# loss 0.03332366794347763
# accuracy.item() 1
# loss 0.14683498442173004
# accuracy.item() 1
# loss 0.007216103840619326
# accuracy.item() 1
# loss 0.23966650664806366
# accuracy.item() 1
# loss 0.00838379468768835
# accuracy.item() 1
# loss 0.025632794946432114
# accuracy.item() 1
# loss 2.807243585586548
# accuracy.item() 0
# loss 0.8691059350967407
# accuracy.item() 0
# loss 0.005803402047604322
# accuracy.item() 1
# loss 0.01076226681470871
# accuracy.item() 1
# loss 0.005111364647746086
# accuracy.item() 1
# loss 0.011852436698973179
# accuracy.item() 1
# loss 0.03309903293848038
# accuracy.item() 1
# loss 0.03742990270256996
# accuracy.item() 1
# loss 0.11301081627607346
# accuracy.item() 1
# loss 0.017533188685774803
# accuracy.item() 1
# loss 0.08386194705963135
# accuracy.item() 1
# loss 0.04789462685585022
# accuracy.item() 1
# loss 0.06301358342170715
# accuracy.item() 1
# loss 0.6762143969535828
# accuracy.item() 1
# loss 0.002443306613713503
# accuracy.item() 1
# loss 9.059495641849935e-05
# accuracy.item() 1
# loss 0.0105305016040802
# accuracy.item() 1
# loss 0.005812883377075195
# accuracy.item() 1
# loss 0.17564579844474792
# accuracy.item() 1
# loss 0.012418328784406185
# accuracy.item() 1
# loss 0.0004568248405121267
# accuracy.item() 1
# loss 0.0332355722784996
# accuracy.item() 1
# loss 0.00026794656878337264
# accuracy.item() 1
# loss 0.0029149444308131933
# accuracy.item() 1
# loss 0.004274636507034302
# accuracy.item() 1
# loss 2.33803129196167
# accuracy.item() 0
# loss 0.5451996326446533
# accuracy.item() 1
# loss 0.025672998279333115
# accuracy.item() 1
# loss 0.04373788833618164
# accuracy.item() 1
# loss 0.006076077930629253
# accuracy.item() 1
# loss 0.011276795528829098
# accuracy.item() 1
# loss 0.013629119843244553
# accuracy.item() 1
# loss 3.902609348297119
# accuracy.item() 0
# loss 0.01143308263272047
# accuracy.item() 1
# loss 0.0220045018941164
# accuracy.item() 1
# loss 3.9698779582977295
# accuracy.item() 0
# loss 0.0612763874232769
# accuracy.item() 1
# loss 0.08576937764883041
# accuracy.item() 1
# loss 0.03756309673190117
# accuracy.item() 1
# loss 0.021717006340622902
# accuracy.item() 1
# loss 0.0024289172142744064
# accuracy.item() 1
# loss 0.07924970239400864
# accuracy.item() 1
# loss 0.005057043395936489
# accuracy.item() 1
# loss 0.0027498311828821898
# accuracy.item() 1
# loss 0.009977703914046288
# accuracy.item() 1
# loss 0.09712952375411987
# accuracy.item() 1
# loss 0.019711444154381752
# accuracy.item() 1
# loss 9.679325739853084e-05
# accuracy.item() 1
# loss 0.4376687705516815
# accuracy.item() 1
# loss 2.1687631607055664
# accuracy.item() 0
# loss 0.0008378094644285738
# accuracy.item() 1
# loss 0.10431234538555145
# accuracy.item() 1
# loss 0.009520367719233036
# accuracy.item() 1
# loss 0.006435740273445845
# accuracy.item() 1
# loss 0.022453835234045982
# accuracy.item() 1
# loss 0.032323382794857025
# accuracy.item() 1
# loss 0.003064580960199237
# accuracy.item() 1
# loss 1.368821620941162
# accuracy.item() 0
# loss 0.0365077406167984
# accuracy.item() 1
# loss 0.2170373648405075
# accuracy.item() 1
# loss 0.41391390562057495
# accuracy.item() 1
# loss 0.20001523196697235
# accuracy.item() 1
# loss 2.262342929840088
# accuracy.item() 0
# loss 0.07451441138982773
# accuracy.item() 1
# loss 0.18786394596099854
# accuracy.item() 1
# loss 0.0109791224822402
# accuracy.item() 1
# loss 0.0011067223967984319
# accuracy.item() 1
# loss 0.017377031967043877
# accuracy.item() 1
# loss 0.023666048422455788
# accuracy.item() 1
# loss 0.023077134042978287
# accuracy.item() 1
# loss 0.16705302894115448
# accuracy.item() 1
# loss 0.0025034775026142597
# accuracy.item() 1
# loss 0.6796832084655762
# accuracy.item() 1
# loss 1.0238490104675293
# accuracy.item() 0
# loss 0.0011462554102763534
# accuracy.item() 1
# loss 0.10953564941883087
# accuracy.item() 1
# loss 3.5533411502838135
# accuracy.item() 0
# loss 0.01486146729439497
# accuracy.item() 1
# loss 0.018524032086133957
# accuracy.item() 1
# loss 0.00015627116954419762
# accuracy.item() 1
# loss 0.10509102046489716
# accuracy.item() 1
# loss 0.006169796921312809
# accuracy.item() 1
# loss 4.911301948595792e-05
# accuracy.item() 1
# loss 4.2676016164477915e-05
# accuracy.item() 1
# loss 0.008569964207708836
# accuracy.item() 1
# loss 0.03008674457669258
# accuracy.item() 1
# loss 0.04129311442375183
# accuracy.item() 1
# loss 0.0063557871617376804
# accuracy.item() 1
# loss 0.049783945083618164
# accuracy.item() 1
# loss 0.0015443552983924747
# accuracy.item() 1
# loss 0.04390447214245796
# accuracy.item() 1
# loss 0.023805394768714905
# accuracy.item() 1
# loss 0.00014554394874721766
# accuracy.item() 1
# loss 0.005019799806177616
# accuracy.item() 1
# loss 1.1920928244535389e-07
# accuracy.item() 1
# loss 0.028624802827835083
# accuracy.item() 1
# loss 0.10774167627096176
# accuracy.item() 1
# loss 0.0027296210173517466
# accuracy.item() 1
# loss 0.0053695267997682095
# accuracy.item() 1
# loss 3.3968265056610107
# accuracy.item() 0
# loss 0.0009095107670873404
# accuracy.item() 1
# loss 0.028600938618183136
# accuracy.item() 1
# loss 0.011533371172845364
# accuracy.item() 1
# loss 2.070676803588867
# accuracy.item() 0
# loss 0.37078243494033813
# accuracy.item() 1
# loss 0.01939253881573677
# accuracy.item() 1
# loss 0.006976412143558264
# accuracy.item() 1
# loss 2.2291887944447808e-05
# accuracy.item() 1
# loss 0.0019033902790397406
# accuracy.item() 1
# loss 3.1736741065979004
# accuracy.item() 0
# loss 0.001190549461171031
# accuracy.item() 1
# loss 1.1259292364120483
# accuracy.item() 0
# loss 0.01992671936750412
# accuracy.item() 1
# loss 0.0016281455755233765
# accuracy.item() 1
# loss 0.0004711233195848763
# accuracy.item() 1
# loss 0.03184890374541283
# accuracy.item() 1
# loss 0.15489719808101654
# accuracy.item() 1
# loss 0.03693647310137749
# accuracy.item() 1
# loss 0.4219245910644531
# accuracy.item() 1
# loss 0.009523319080471992
# accuracy.item() 1
# loss 0.025093749165534973
# accuracy.item() 1
# loss 0.3168400228023529
# accuracy.item() 1
# loss 0.0015242397785186768
# accuracy.item() 1
# loss 0.03449629619717598
# accuracy.item() 1
# loss 0.27346178889274597
# accuracy.item() 1
# loss 0.0007189311436377466
# accuracy.item() 1
# loss 0.00041559641249477863
# accuracy.item() 1
# loss 0.0013562776148319244
# accuracy.item() 1
# loss 0.01323509681969881
# accuracy.item() 1
# loss 0.023931685835123062
# accuracy.item() 1
# loss 0.0005063920398242772
# accuracy.item() 1
# loss 0.0070023369044065475
# accuracy.item() 1
# loss 0.0017273995326831937
# accuracy.item() 1
# loss 0.017139999195933342
# accuracy.item() 1
# loss 0.011740044690668583
# accuracy.item() 1
# loss 0.009133581072092056
# accuracy.item() 1
# loss 0.08257308602333069
# accuracy.item() 1
# loss 0.0005367745761759579
# accuracy.item() 1
# loss 1.6066701412200928
# accuracy.item() 0
# loss 0.0
# accuracy.item() 1
# loss 0.058314286172389984
# accuracy.item() 1
# loss 0.00030632095877081156
# accuracy.item() 1
# loss 0.01123047061264515
# accuracy.item() 1
# loss 2.7418097943154862e-06
# accuracy.item() 1
# loss 0.08302004635334015
# accuracy.item() 1
# loss 0.039928458631038666
# accuracy.item() 1
# loss 0.08741214871406555
# accuracy.item() 1
# loss 0.01859096623957157
# accuracy.item() 1
# loss 0.004604807589203119
# accuracy.item() 1
# loss 0.00048315772437490523
# accuracy.item() 1
# loss 0.14988282322883606
# accuracy.item() 1
# loss 0.0005769256968051195
# accuracy.item() 1
# loss 0.04967221990227699
# accuracy.item() 1
# loss 0.00596374599263072
# accuracy.item() 1
# loss 0.02879623882472515
# accuracy.item() 1
# loss 0.04048715904355049
# accuracy.item() 1
# loss 0.29755690693855286
# accuracy.item() 1
# loss 0.3550873100757599
# accuracy.item() 1
# loss 0.08831781148910522
# accuracy.item() 1
# loss 9.536738616588991e-07
# accuracy.item() 1
# loss 0.0007722970913164318
# accuracy.item() 1
# loss 0.2535948157310486
# accuracy.item() 1
# loss 0.04919807240366936
# accuracy.item() 1
# loss 0.010896466672420502
# accuracy.item() 1
# loss 0.1273787021636963
# accuracy.item() 1
# loss 0.00015031162183731794
# accuracy.item() 1
# loss 0.019124288111925125
# accuracy.item() 1
# loss 3.233243942260742
# accuracy.item() 0
# loss 0.017021285369992256
# accuracy.item() 1
# loss 0.0007185738068073988
# accuracy.item() 1
# loss 1.5346837043762207
# accuracy.item() 0
# loss 0.0015411416534334421
# accuracy.item() 1
# loss 0.005128087010234594
# accuracy.item() 1
# loss 3.302042750874534e-05
# accuracy.item() 1
# loss 0.006311128847301006
# accuracy.item() 1
# loss 0.10387168824672699
# accuracy.item() 1
# loss 0.00014137222024146467
# accuracy.item() 1
# loss 0.05327548459172249
# accuracy.item() 1
# loss 0.014827876351773739
# accuracy.item() 1
# loss 0.06942544132471085
# accuracy.item() 1
# loss 1.3199796676635742
# accuracy.item() 0
# loss 0.00020895205670967698
# accuracy.item() 1
# loss 0.05220140144228935
# accuracy.item() 1
# loss 0.011591112241148949
# accuracy.item() 1
# loss 0.05694959685206413
# accuracy.item() 1
# loss 2.658006191253662
# accuracy.item() 0
# loss 0.00021681819634977728
# accuracy.item() 1
# loss 0.0019302800064906478
# accuracy.item() 1
# loss 0.0002493547508493066
# accuracy.item() 1
# loss 0.5526596307754517
# accuracy.item() 1
# loss 0.03254265338182449
# accuracy.item() 1
# loss 0.0024073924869298935
# accuracy.item() 1
# loss 0.8255243897438049
# accuracy.item() 0
# loss 0.28202390670776367
# accuracy.item() 1
# loss 0.009035887196660042
# accuracy.item() 1
# loss 0.03372126817703247
# accuracy.item() 1
# loss 0.013550798408687115
# accuracy.item() 1
# loss 0.0030373651534318924
# accuracy.item() 1
# loss 0.01160218846052885
# accuracy.item() 1
# loss 0.006889516953378916
# accuracy.item() 1
# loss 0.002676716074347496
# accuracy.item() 1
# loss 0.40723690390586853
# accuracy.item() 1
# loss 0.629082441329956
# accuracy.item() 1
# loss 0.009323272854089737
# accuracy.item() 1
# loss 0.019948454573750496
# accuracy.item() 1
# loss 0.00018082413589581847
# accuracy.item() 1
# loss 0.006747911684215069
# accuracy.item() 1
# loss 0.002072450239211321
# accuracy.item() 1
# loss 0.0031040364410728216
# accuracy.item() 1
# loss 0.08217127621173859
# accuracy.item() 1
# loss 0.010274730622768402
# accuracy.item() 1
# loss 0.20061947405338287
# accuracy.item() 1
# loss 0.08356110751628876
# accuracy.item() 1
# loss 0.05240606144070625
# accuracy.item() 1
# loss 0.004272618796676397
# accuracy.item() 1
# loss 1.046499252319336
# accuracy.item() 0
# loss 0.005694476887583733
# accuracy.item() 1
# loss 0.11895854026079178
# accuracy.item() 1
# loss 0.7222805619239807
# accuracy.item() 0
# loss 0.118136465549469
# accuracy.item() 1
# loss 0.09747151285409927
# accuracy.item() 1
# loss 0.006544111296534538
# accuracy.item() 1
# loss 0.7924983501434326
# accuracy.item() 0
# loss 0.047006405889987946
# accuracy.item() 1
# loss 0.0021878371480852365
# accuracy.item() 1
# loss 0.05052260309457779
# accuracy.item() 1
# loss 0.6702083349227905
# accuracy.item() 1
# loss 0.0002574589161667973
# accuracy.item() 1
# loss 0.009539732709527016
# accuracy.item() 1
# loss 0.04883110150694847
# accuracy.item() 1
# loss 0.05991820618510246
# accuracy.item() 1
# loss 0.08892767876386642
# accuracy.item() 1
# loss 0.0317479744553566
# accuracy.item() 1
# loss 0.012238879688084126
# accuracy.item() 1
# loss 0.005254980642348528
# accuracy.item() 1
# loss 0.011965052224695683
# accuracy.item() 1
# loss 0.0028576513286679983
# accuracy.item() 1
# loss 0.1089247614145279
# accuracy.item() 1
# loss 7.510157047363464e-06
# accuracy.item() 1
# loss 0.02096247300505638
# accuracy.item() 1
# loss 0.0016304069431498647
# accuracy.item() 1
# loss 0.00119138287845999
# accuracy.item() 1
# loss 0.014982552267611027
# accuracy.item() 1
# loss 0.02892352268099785
# accuracy.item() 1
# loss 0.0015123370103538036
# accuracy.item() 1
# loss 0.002246477175503969
# accuracy.item() 1
# loss 0.10144934803247452
# accuracy.item() 1
# loss 0.21304018795490265
# accuracy.item() 1
# loss 0.7438308000564575
# accuracy.item() 1
# loss 0.021704407408833504
# accuracy.item() 1
# loss 0.25214871764183044
# accuracy.item() 1
# loss 0.005550093948841095
# accuracy.item() 1
# loss 0.05503925681114197
# accuracy.item() 1
# loss 0.4298674762248993
# accuracy.item() 1
# loss 0.0165631715208292
# accuracy.item() 1
# loss 0.03032200038433075
# accuracy.item() 1
# loss 0.014521154575049877
# accuracy.item() 1
# loss 3.3374805450439453
# accuracy.item() 0
# loss 0.010278978385031223
# accuracy.item() 1
# loss 0.006101434119045734
# accuracy.item() 1
# loss 0.0046682897955179214
# accuracy.item() 1
# loss 0.30703696608543396
# accuracy.item() 1
# loss 1.1640901565551758
# accuracy.item() 0
# loss 0.057683881372213364
# accuracy.item() 1
# loss 0.007365216501057148
# accuracy.item() 1
# loss 0.04203955456614494
# accuracy.item() 1
# loss 0.05183473974466324
# accuracy.item() 1
# loss 0.008364643901586533
# accuracy.item() 1
# loss 0.16015006601810455
# accuracy.item() 1
# loss 0.0016368337674066424
# accuracy.item() 1
# loss 0.010761677287518978
# accuracy.item() 1
# loss 0.7016317844390869
# accuracy.item() 1
# loss 0.17806373536586761
# accuracy.item() 1
# loss 4.8993817472364753e-05
# accuracy.item() 1
# loss 0.0066504571586847305
# accuracy.item() 1
# loss 0.00012778419477399439
# accuracy.item() 1
# loss 0.0014194899704307318
# accuracy.item() 1
# loss 0.05689813196659088
# accuracy.item() 1
# loss 0.016409561038017273
# accuracy.item() 1
# loss 0.0011831672163680196
# accuracy.item() 1
# loss 0.0035476861521601677
# accuracy.item() 1
# loss 0.03959290683269501
# accuracy.item() 1
# loss 0.21681943535804749
# accuracy.item() 1
# loss 3.081188678741455
# accuracy.item() 0
# loss 0.042977072298526764
# accuracy.item() 1
# loss 0.005464734509587288
# accuracy.item() 1
# loss 0.09200078994035721
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.09691163152456284
# accuracy.item() 1
# loss 1.7531086206436157
# accuracy.item() 0
# loss 0.010138441808521748
# accuracy.item() 1
# loss 0.009583774022758007
# accuracy.item() 1
# loss 0.01134845893830061
# accuracy.item() 1
# loss 1.4638630151748657
# accuracy.item() 0
# loss 0.004209586419165134
# accuracy.item() 1
# loss 0.0522649846971035
# accuracy.item() 1
# loss 8.21318244561553e-05
# accuracy.item() 1
# loss 0.03581524267792702
# accuracy.item() 1
# loss 0.002197353169322014
# accuracy.item() 1
# loss 0.006446044892072678
# accuracy.item() 1
# loss 0.0007934997556731105
# accuracy.item() 1
# loss 2.7417760065873154e-05
# accuracy.item() 1
# loss 0.015194620005786419
# accuracy.item() 1
# loss 0.00014399446081370115
# accuracy.item() 1
# loss 0.006725887302309275
# accuracy.item() 1
# loss 0.010083449073135853
# accuracy.item() 1
# loss 0.002654958749189973
# accuracy.item() 1
# loss 0.0429985411465168
# accuracy.item() 1
# loss 0.002449014689773321
# accuracy.item() 1
# loss 0.098809152841568
# accuracy.item() 1
# loss 0.006136741489171982
# accuracy.item() 1
# loss 0.16110333800315857
# accuracy.item() 1
# loss 4.351044481154531e-05
# accuracy.item() 1
# loss 0.0006108802044764161
# accuracy.item() 1
# loss 0.012606455944478512
# accuracy.item() 1
# loss 0.07845526933670044
# accuracy.item() 1
# loss 4.875540980719961e-05
# accuracy.item() 1
# loss 0.14150883257389069
# accuracy.item() 1
# loss 0.028607426211237907
# accuracy.item() 1
# loss 0.08892418444156647
# accuracy.item() 1
# loss 0.003095598891377449
# accuracy.item() 1
# loss 0.0018572239205241203
# accuracy.item() 1
# loss 7.557583012385294e-05
# accuracy.item() 1
# loss 0.004095738288015127
# accuracy.item() 1
# loss 0.005472796503454447
# accuracy.item() 1
# loss 0.019122768193483353
# accuracy.item() 1
# loss 0.5192133784294128
# accuracy.item() 1
# loss 0.001500314916484058
# accuracy.item() 1
# loss 0.027566226199269295
# accuracy.item() 1
# loss 0.009406532160937786
# accuracy.item() 1
# loss 0.0332958810031414
# accuracy.item() 1
# loss 0.009208234027028084
# accuracy.item() 1
# loss 0.1392298936843872
# accuracy.item() 1
# loss 0.012198134325444698
# accuracy.item() 1
# loss 0.002715235808864236
# accuracy.item() 1
# loss 0.008424459025263786
# accuracy.item() 1
# loss 0.052272453904151917
# accuracy.item() 1
# loss 0.004081848077476025
# accuracy.item() 1
# loss 0.0037237131036818027
# accuracy.item() 1
# loss 0.02166159637272358
# accuracy.item() 1
# loss 0.007867774926126003
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.003136598039418459
# accuracy.item() 1
# loss 1.2767651081085205
# accuracy.item() 0
# loss 0.09559117257595062
# accuracy.item() 1
# loss 0.004212079104036093
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 1.9671849012374878
# accuracy.item() 0
# loss 0.023988250643014908
# accuracy.item() 1
# loss 1.4284121990203857
# accuracy.item() 0
# loss 0.02206350862979889
# accuracy.item() 1
# loss 0.042117390781641006
# accuracy.item() 1
# loss 0.6829602718353271
# accuracy.item() 1
# loss 0.14326860010623932
# accuracy.item() 1
# loss 0.026208247989416122
# accuracy.item() 1
# loss 5.364403477869928e-06
# accuracy.item() 1
# loss 0.003796632867306471
# accuracy.item() 1
# loss 0.000498289882671088
# accuracy.item() 1
# loss 0.03609457612037659
# accuracy.item() 1
# loss 0.05014568939805031
# accuracy.item() 1
# loss 0.0001397035230183974
# accuracy.item() 1
# loss 0.001176023157313466
# accuracy.item() 1
# loss 0.0012752028414979577
# accuracy.item() 1
# loss 0.0011597104603424668
# accuracy.item() 1
# loss 0.0010926711838692427
# accuracy.item() 1
# loss 0.0675489529967308
# accuracy.item() 1
# loss 0.0003152588615193963
# accuracy.item() 1
# loss 8.463501580990851e-05
# accuracy.item() 1
# loss 0.013079562224447727
# accuracy.item() 1
# loss 0.1890176683664322
# accuracy.item() 1
# loss 0.008596912026405334
# accuracy.item() 1
# loss 0.05452057719230652
# accuracy.item() 1
# loss 0.0004990047891624272
# accuracy.item() 1
# loss 0.04396756365895271
# accuracy.item() 1
# loss 0.0018715023761615157
# accuracy.item() 1
# loss 0.1258467137813568
# accuracy.item() 1
# loss 0.009208234027028084
# accuracy.item() 1
# loss 0.0004969792207702994
# accuracy.item() 1
# loss 0.059540435671806335
# accuracy.item() 1
# loss 0.013103682547807693
# accuracy.item() 1
# loss 0.05197089537978172
# accuracy.item() 1
# loss 4.522664546966553
# accuracy.item() 0
# loss 0.0007795632118359208
# accuracy.item() 1
# loss 0.0034086955711245537
# accuracy.item() 1
# loss 0.011389710940420628
# accuracy.item() 1
# loss 6.174850568640977e-05
# accuracy.item() 1
# loss 0.009922347962856293
# accuracy.item() 1
# loss 0.07117586582899094
# accuracy.item() 1
# loss 0.0505051463842392
# accuracy.item() 1
# loss 0.0005355831235647202
# accuracy.item() 1
# loss 0.00022504181833937764
# accuracy.item() 1
# loss 0.020842811092734337
# accuracy.item() 1
# loss 2.9937872886657715
# accuracy.item() 0
# loss 6.592056161025539e-05
# accuracy.item() 1
# loss 0.0013093716697767377
# accuracy.item() 1
# loss 0.04177125170826912
# accuracy.item() 1
# loss 0.012759946286678314
# accuracy.item() 1
# loss 1.811964830267243e-05
# accuracy.item() 1
# loss 0.004636134020984173
# accuracy.item() 1
# loss 0.0027277187909930944
# accuracy.item() 1
# loss 0.0026773104909807444
# accuracy.item() 1
# loss 0.41717904806137085
# accuracy.item() 1
# loss 0.00013290952483657748
# accuracy.item() 1
# loss 0.20182083547115326
# accuracy.item() 1
# loss 0.003298320807516575
# accuracy.item() 1
# loss 0.00379592040553689
# accuracy.item() 1
# loss 0.0028247239533811808
# accuracy.item() 1
# loss 0.0405733585357666
# accuracy.item() 1
# loss 0.3318501114845276
# accuracy.item() 1
# loss 0.0035813022404909134
# accuracy.item() 1
# loss 0.0017005043337121606
# accuracy.item() 1
# loss 0.0011517327511683106
# accuracy.item() 1
# loss 0.0038627786561846733
# accuracy.item() 1
# loss 5.638440416078083e-05
# accuracy.item() 1
# loss 0.0638846829533577
# accuracy.item() 1
# loss 0.0883614644408226
# accuracy.item() 1
# loss 3.3177666664123535
# accuracy.item() 0
# loss 1.9416790008544922
# accuracy.item() 0
# loss 0.28990185260772705
# accuracy.item() 1
# loss 0.0004880429187323898
# accuracy.item() 1
# loss 0.017811235040426254
# accuracy.item() 1
# loss 0.01509281899780035
# accuracy.item() 1
# loss 6.769359588623047
# accuracy.item() 0
# loss 0.06250137090682983
# accuracy.item() 1
# loss 0.0048265615478158
# accuracy.item() 1
# loss 0.04866238683462143
# accuracy.item() 1
# loss 0.057390592992305756
# accuracy.item() 1
# loss 0.022844476625323296
# accuracy.item() 1
# loss 0.005679897032678127
# accuracy.item() 1
# loss 0.6133450865745544
# accuracy.item() 1
# loss 0.138719379901886
# accuracy.item() 1
# loss 3.576272320060525e-06
# accuracy.item() 1
# loss 0.035202253609895706
# accuracy.item() 1
# loss 0.00024351492174901068
# accuracy.item() 1
# loss 2.245758295059204
# accuracy.item() 0
# loss 3.373566141817719e-05
# accuracy.item() 1
# loss 0.609058678150177
# accuracy.item() 1
# ...
# accuracy.item() 1
# loss 0.0004447901446837932
# accuracy.item() 1
# loss 1.3589766240329482e-05
# accuracy.item() 1
# loss 5.674201020156033e-05
# accuracy.item() 1
# loss 0.00015352977789007127
# accuracy.item() 1
# loss 3.576278118089249e-07
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 3.683499380713329e-05
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.0010890988633036613
# accuracy.item() 1
# loss 0.0001225396408699453
# accuracy.item() 1
# loss 0.008072606287896633
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 9.190614218823612e-05
# accuracy.item() 1
# loss 1.640248417854309
# accuracy.item() 0
# loss 0.00013124081306159496
# accuracy.item() 1
# loss 0.00038354191929101944
# accuracy.item() 1
# loss 0.10674244910478592
# accuracy.item() 1
# loss 0.028542084619402885
# accuracy.item() 1
# loss 0.024505093693733215
# accuracy.item() 1
# loss 0.001520430902019143
# accuracy.item() 1
# loss 1.5735502529423684e-05
# accuracy.item() 1
# loss 0.04645361378788948
# accuracy.item() 1
# loss 0.00179903709795326
# accuracy.item() 1
# loss 2.1457441107486375e-05
# accuracy.item() 1
# loss 0.0014868644066154957
# accuracy.item() 1
# loss 0.4782567024230957
# accuracy.item() 1
# loss 0.00013517419574782252
# accuracy.item() 1
# loss 1.8000440832111053e-05
# accuracy.item() 1
# loss 0.03570999577641487
# accuracy.item() 1
# loss 0.39201825857162476
# accuracy.item() 1
# loss 0.533778727054596
# accuracy.item() 1
# loss 0.0551014244556427
# accuracy.item() 1
# loss 0.0008135108510032296
# accuracy.item() 1
# loss 1.5258672647178173e-05
# accuracy.item() 1
# loss 0.006042900960892439
# accuracy.item() 1
# loss 4.768370445162873e-07
# accuracy.item() 1
# loss 1.4066597032069694e-05
# accuracy.item() 1
# loss 0.00029392691794782877
# accuracy.item() 1
# loss 0.0003530356043484062
# accuracy.item() 1
# loss 1.2701122760772705
# accuracy.item() 0
# loss 0.00013136000779923052
# accuracy.item() 1
# loss 0.00012158608296886086
# accuracy.item() 1
# loss 0.0017395378090441227
# accuracy.item() 1
# loss 1.811964830267243e-05
# accuracy.item() 1
# loss 0.0018167671514675021
# accuracy.item() 1
# loss 6.556489552167477e-06
# accuracy.item() 1
# loss 1.1920858014491387e-05
# accuracy.item() 1
# loss 0.051541768014431
# accuracy.item() 1
# loss 0.0016623024130240083
# accuracy.item() 1
# loss 0.00010466027742950246
# accuracy.item() 1
# loss 0.44812798500061035
# accuracy.item() 1
# loss 4.768370445162873e-07
# accuracy.item() 1
# loss 0.005562778562307358
# accuracy.item() 1
# loss 0.0017891604220494628
# accuracy.item() 1
# loss 2.3245540432981215e-05
# accuracy.item() 1
# loss 3.2782016205601394e-05
# accuracy.item() 1
# loss 4.8874615458771586e-05
# accuracy.item() 1
# loss 0.002915182150900364
# accuracy.item() 1
# loss 1.1920928244535389e-07
# accuracy.item() 1
# loss 0.00020740265608765185
# accuracy.item() 1
# loss 0.00010609064338495955
# accuracy.item() 1
# loss 0.002683730563148856
# accuracy.item() 1
# loss 0.0014215136179700494
# accuracy.item() 1
# loss 0.0016079128254204988
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.09170260280370712
# accuracy.item() 1
# loss 8.344646857949556e-07
# accuracy.item() 1
# loss 0.00018726025882642716
# accuracy.item() 1
# loss 2.6940935640595853e-05
# accuracy.item() 1
# loss 8.999896090244874e-05
# accuracy.item() 1
# loss 0.00029380773776210845
# accuracy.item() 1
# loss 8.344646857949556e-07
# accuracy.item() 1
# loss 9.798523387871683e-05
# accuracy.item() 1
# loss 0.0006964165368117392
# accuracy.item() 1
# loss 0.0025289240293204784
# accuracy.item() 1
# loss 2.3841830625315197e-06
# accuracy.item() 1
# loss 1.8954096958623268e-05
# accuracy.item() 1
# loss 9.536738616588991e-07
# accuracy.item() 1
# loss 0.02538597211241722
# accuracy.item() 1
# loss 0.008769216015934944
# accuracy.item() 1
# loss 0.0021572669502347708
# accuracy.item() 1
# loss 0.003107126336544752
# accuracy.item() 1
# loss 1.9061806201934814
# accuracy.item() 0
# loss 4.7801782784517854e-05
# accuracy.item() 1
# loss 0.0015881556319072843
# accuracy.item() 1
# loss 0.0007470439304597676
# accuracy.item() 1
# loss 6.508615479106084e-05
# accuracy.item() 1
# loss 0.0003194298769813031
# accuracy.item() 1
# loss 0.00015186110977083445
# accuracy.item() 1
# loss 1.0728830375228426e-06
# accuracy.item() 1
# loss 2.1815061700181104e-05
# accuracy.item() 1
# loss 1.7165990357170813e-05
# accuracy.item() 1
# loss 0.005360871087759733
# accuracy.item() 1
# loss 0.019280288368463516
# accuracy.item() 1
# loss 4.399153232574463
# accuracy.item() 0
# loss 4.2437604861333966e-05
# accuracy.item() 1
# loss 0.00016962042718660086
# accuracy.item() 1
# loss 1.8954096958623268e-05
# accuracy.item() 1
# loss 0.0005678709712810814
# accuracy.item() 1
# loss 0.0006665153778158128
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 6.151010165922344e-05
# accuracy.item() 1
# loss 0.0018631733255460858
# accuracy.item() 1
# loss 1.4305104514278355e-06
# accuracy.item() 1
# loss 0.0072465199045836926
# accuracy.item() 1
# loss 0.007254686206579208
# accuracy.item() 1
# loss 2.047959566116333
# accuracy.item() 0
# loss 0.0013359201839193702
# accuracy.item() 1
# loss 0.14962932467460632
# accuracy.item() 1
# loss 0.009248864836990833
# accuracy.item() 1
# loss 0.0013529442949220538
# accuracy.item() 1
# loss 3.576272320060525e-06
# accuracy.item() 1
# loss 3.4465954303741455
# accuracy.item() 0
# loss 0.0001358893496217206
# accuracy.item() 1
# loss 3.266040086746216
# accuracy.item() 0
# loss 0.0027465024031698704
# accuracy.item() 1
# loss 1.8358061424805783e-05
# accuracy.item() 1
# loss 0.0002821285743266344
# accuracy.item() 1
# loss 0.005024544429033995
# accuracy.item() 1
# loss 0.007198587525635958
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.26977527141571045
# accuracy.item() 1
# loss 0.00016032364510465413
# accuracy.item() 1
# loss 0.00045277358731254935
# accuracy.item() 1
# loss 0.0017401328077539802
# accuracy.item() 1
# loss 0.009353861212730408
# accuracy.item() 1
# loss 1.7345904111862183
# accuracy.item() 0
# loss 0.20230919122695923
# accuracy.item() 1
# loss 0.0028330450877547264
# accuracy.item() 1
# loss 4.815939246327616e-05
# accuracy.item() 1
# loss 0.008142017759382725
# accuracy.item() 1
# loss 0.0015572099946439266
# accuracy.item() 1
# loss 0.00018606838420964777
# accuracy.item() 1
# loss 0.00015710550360381603
# accuracy.item() 1
# loss 0.0013722298899665475
# accuracy.item() 1
# loss 0.002345907734706998
# accuracy.item() 1
# loss 2.6225699912174605e-05
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.0008244690834544599
# accuracy.item() 1
# loss 0.016073176637291908
# accuracy.item() 1
# loss 0.0009223736124113202
# accuracy.item() 1
# loss 3.838465272565372e-05
# accuracy.item() 1
# loss 4.768370445162873e-07
# accuracy.item() 1
# loss 1.0415723323822021
# accuracy.item() 0
# loss 0.0002460177056491375
# accuracy.item() 1
# loss 0.06256072223186493
# accuracy.item() 1
# loss 0.015485405921936035
# accuracy.item() 1
# loss 5.817244164063595e-05
# accuracy.item() 1
# loss 0.004942105617374182
# accuracy.item() 1
# loss 5.483612312673358e-06
# accuracy.item() 1
# loss 0.00037281715776771307
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.009023955091834068
# accuracy.item() 1
# loss 0.0007049936102703214
# accuracy.item() 1
# loss 0.00020525732543319464
# accuracy.item() 1
# loss 0.00034540885826572776
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.008544670417904854
# accuracy.item() 1
# loss 0.002550446195527911
# accuracy.item() 1
# loss 0.016751226037740707
# accuracy.item() 1
# loss 0.0004814896092284471
# accuracy.item() 1
# loss 0.03220045566558838
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.0004207202873658389
# accuracy.item() 1
# loss 1.1920922133867862e-06
# accuracy.item() 1
# loss 5.364403477869928e-06
# accuracy.item() 1
# loss 0.0020718553569167852
# accuracy.item() 1
# loss 8.821098163025454e-05
# accuracy.item() 1
# loss 2.9801878554280847e-05
# accuracy.item() 1
# loss 1.2040065485052764e-05
# accuracy.item() 1
# loss 2.0265558760002023e-06
# accuracy.item() 1
# loss 3.576214658096433e-05
# accuracy.item() 1
# loss 2.52720492426306e-05
# accuracy.item() 1
# loss 0.0002858230145648122
# accuracy.item() 1
# loss 1.1920928244535389e-07
# accuracy.item() 1
# loss 9.572047565598041e-05
# accuracy.item() 1
# loss 0.0015331668546423316
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.0006987990345805883
# accuracy.item() 1
# loss 0.00047672350774519145
# accuracy.item() 1
# loss 5.245195097813848e-06
# accuracy.item() 1
# loss 1.7523612768854946e-05
# accuracy.item() 1
# loss 4.053033626405522e-05
# accuracy.item() 1
# loss 0.20014259219169617
# accuracy.item() 1
# loss 1.6222307682037354
# accuracy.item() 0
# loss 3.182837463100441e-05
# accuracy.item() 1
# loss 5.602820692729438e-06
# accuracy.item() 1
# loss 4.029192859889008e-05
# accuracy.item() 1
# loss 3.3378546504536644e-06
# accuracy.item() 1
# loss 0.0006856950931251049
# accuracy.item() 1
# loss 7.152555099310121e-07
# accuracy.item() 1
# loss 0.1225581094622612
# accuracy.item() 1
# loss 0.00039736481267027557
# accuracy.item() 1
# loss 0.0022266136948019266
# accuracy.item() 1
# loss 0.0006934384000487626
# accuracy.item() 1
# loss 0.025849470868706703
# accuracy.item() 1
# loss 2.706014311115723e-05
# accuracy.item() 1
# loss 0.004454095847904682
# accuracy.item() 1
# loss 1.1920922133867862e-06
# accuracy.item() 1
# loss 0.007683249190449715
# accuracy.item() 1
# loss 0.00011693747364915907
# accuracy.item() 1
# loss 0.00024351492174901068
# accuracy.item() 1
# loss 3.099436753473128e-06
# accuracy.item() 1
# loss 0.002406084444373846
# accuracy.item() 1
# loss 0.00018046658078674227
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 2.145764938177308e-06
# accuracy.item() 1
# loss 0.001212695729918778
# accuracy.item() 1
# loss 0.001450201845727861
# accuracy.item() 1
# loss 0.0006685405969619751
# accuracy.item() 1
# loss 0.0013271104544401169
# accuracy.item() 1
# loss 0.006372726056724787
# accuracy.item() 1
# loss 0.004034950863569975
# accuracy.item() 1
# loss 0.5099821090698242
# accuracy.item() 1
# loss 0.0017204972682520747
# accuracy.item() 1
# loss 0.0005852655158378184
# accuracy.item() 1
# loss 0.03785686194896698
# accuracy.item() 1
# loss 0.030158575624227524
# accuracy.item() 1
# loss 0.00018404220463708043
# accuracy.item() 1
# loss 0.000102037942269817
# accuracy.item() 1
# loss 1.7881233361549675e-05
# accuracy.item() 1
# loss 0.11477985978126526
# accuracy.item() 1
# loss 1.6689286894688848e-06
# accuracy.item() 1
# loss 3.981510963058099e-05
# accuracy.item() 1
# loss 7.748573807475623e-06
# accuracy.item() 1
# loss 0.0001234931987710297
# accuracy.item() 1
# loss 0.0560678094625473
# accuracy.item() 1
# loss 2.407998726994265e-05
# accuracy.item() 1
# loss 0.0018914919346570969
# accuracy.item() 1
# loss 0.0002269487304147333
# accuracy.item() 1
# loss 0.06377172470092773
# accuracy.item() 1
# loss 0.00028761065914295614
# accuracy.item() 1
# loss 2.002696055569686e-05
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.42310386896133423
# accuracy.item() 1
# loss 0.000366263062460348
# accuracy.item() 1
# loss 0.369519978761673
# accuracy.item() 1
# loss 0.0014946014853194356
# accuracy.item() 1
# loss 5.960462772236497e-07
# accuracy.item() 1
# loss 6.079655122448457e-06
# accuracy.item() 1
# loss 1.1005148887634277
# accuracy.item() 0
# loss 7.271740287251305e-06
# accuracy.item() 1
# loss 5.686121585313231e-05
# accuracy.item() 1
# loss 3.576278118089249e-07
# accuracy.item() 1
# loss 7.354942499659956e-05
# accuracy.item() 1
# loss 0.042074643075466156
# accuracy.item() 1
# loss 1.2993727978027891e-05
# accuracy.item() 1
# loss 0.0037254944909363985
# accuracy.item() 1
# loss 0.7647634744644165
# accuracy.item() 0
# loss 0.00018976318824570626
# accuracy.item() 1
# loss 0.00021765247220173478
# accuracy.item() 1
# loss 2.2411095415009186e-05
# accuracy.item() 1
# loss 3.5349934101104736
# accuracy.item() 0
# loss 0.1228199303150177
# accuracy.item() 1
# loss 2.7418097943154862e-06
# accuracy.item() 1
# loss 0.0004674295778386295
# accuracy.item() 1
# loss 2.7179348762729205e-05
# accuracy.item() 1
# loss 3.158996332786046e-05
# accuracy.item() 1
# loss 4.8636207793606445e-05
# accuracy.item() 1
# loss 1.750952959060669
# accuracy.item() 0
# loss 1.7404405298293568e-05
# accuracy.item() 1
# loss 3.683499380713329e-05
# accuracy.item() 1
# loss 2.098061486321967e-05
# accuracy.item() 1
# loss 0.00033539868309162557
# accuracy.item() 1
# loss 1.5497195136049413e-06
# accuracy.item() 1
# loss 0.00045849301386624575
# accuracy.item() 1
# loss 0.00032228996860794723
# accuracy.item() 1
# loss 1.4543427823809907e-05
# accuracy.item() 1
# loss 0.0002324311062693596
# accuracy.item() 1
# loss 7.116541382856667e-05
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.000966915744356811
# accuracy.item() 1
# loss 0.0025175088085234165
# accuracy.item() 1
# loss 1.7762025890988298e-05
# accuracy.item() 1
# loss 0.0013999671209603548
# accuracy.item() 1
# loss 0.0005029367166571319
# accuracy.item() 1
# loss 1.5497195136049413e-06
# accuracy.item() 1
# loss 0.000303818320389837
# accuracy.item() 1
# loss 6.19869097135961e-05
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 4.994744449504651e-05
# accuracy.item() 1
# loss 0.009715298190712929
# accuracy.item() 1
# loss 0.06098717823624611
# accuracy.item() 1
# loss 0.0016813441179692745
# accuracy.item() 1
# loss 9.50984001159668
# accuracy.item() 0
# loss 7.867782187531702e-06
# accuracy.item() 1
# loss 0.00034457468427717686
# accuracy.item() 1
# loss 4.3987260141875595e-05
# accuracy.item() 1
# loss 0.0023624387104064226
# accuracy.item() 1
# loss 5.113606929779053
# accuracy.item() 0
# loss 0.0006152882124297321
# accuracy.item() 1
# loss 1.680836794548668e-05
# accuracy.item() 1
# loss 1.1324817933200393e-05
# accuracy.item() 1
# loss 0.00029213930247351527
# accuracy.item() 1
# loss 7.080780778778717e-05
# accuracy.item() 1
# loss 0.00013529339048545808
# accuracy.item() 1
# loss 1.7404405298293568e-05
# accuracy.item() 1
# loss 9.65590606938349e-06
# accuracy.item() 1
# loss 0.0010617101797834039
# accuracy.item() 1
# loss 2.276871418871451e-05
# accuracy.item() 1
# loss 0.0055069406516849995
# accuracy.item() 1
# loss 0.08126959204673767
# accuracy.item() 1
# loss 1.4305012882687151e-05
# accuracy.item() 1
# loss 1.1920928244535389e-07
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 6.365573790390044e-05
# accuracy.item() 1
# loss 0.0002731903805397451
# accuracy.item() 1
# loss 0.00010775939153973013
# accuracy.item() 1
# loss 6.174850568640977e-05
# accuracy.item() 1
# loss 0.0008225633064284921
# accuracy.item() 1
# loss 0.17000797390937805
# accuracy.item() 1
# loss 0.0009598892065696418
# accuracy.item() 1
# loss 0.00029762129997834563
# accuracy.item() 1
# loss 0.03168746083974838
# accuracy.item() 1
# loss 6.401333666872233e-05
# accuracy.item() 1
# loss 3.576278118089249e-07
# accuracy.item() 1
# loss 4.577531944960356e-05
# accuracy.item() 1
# loss 0.003993988502770662
# accuracy.item() 1
# loss 0.01089858915656805
# accuracy.item() 1
# loss 8.344646857949556e-07
# accuracy.item() 1
# loss 2.728714942932129
# accuracy.item() 0
# loss 9.858569145202637
# accuracy.item() 0
# loss 1.9073468138230965e-06
# accuracy.item() 1
# loss 4.043375015258789
# accuracy.item() 0
# loss 0.0012646066024899483
# accuracy.item() 1
# loss 0.006334228441119194
# accuracy.item() 1
# loss 0.11017713695764542
# accuracy.item() 1
# loss 0.042179904878139496
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.0027516144327819347
# accuracy.item() 1
# loss 0.00032824851223267615
# accuracy.item() 1
# loss 7.033323527139146e-06
# accuracy.item() 1
# loss 0.0005648924270644784
# accuracy.item() 1
# loss 0.11062441021203995
# accuracy.item() 1
# loss 3.194758028257638e-05
# accuracy.item() 1
# loss 0.00011276562872808427
# accuracy.item() 1
# loss 0.0001408954558428377
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.0009018882992677391
# accuracy.item() 1
# loss 0.5795598030090332
# accuracy.item() 1
# loss 6.5205356804654e-05
# accuracy.item() 1
# loss 0.00013529339048545808
# accuracy.item() 1
# loss 0.0005791893927380443
# accuracy.item() 1
# loss 0.0010480155469849706
# accuracy.item() 1
# loss 2.3245540432981215e-05
# accuracy.item() 1
# loss 0.0
# accuracy.item() 1
# loss 0.002773845102638006
# accuracy.item() 1
# loss 3.576278118089249e-07
# accuracy.item() 1
# loss 3.8742269680369645e-05
# accuracy.item() 1
# loss 0.0004027270770166069
# accuracy.item() 1
# loss 0.0011367294937372208
# accuracy.item() 1
# loss 0.00026174934464506805
# accuracy.item() 1
# loss 0.0035276107955724
# accuracy.item() 1
# loss 0.01621311716735363
# accuracy.item() 1
# loss 0.002268243348225951
# accuracy.item() 1
# loss 0.00013684290752280504
# accuracy.item() 1
# loss 0.021486716344952583
# accuracy.item() 1
# loss 0.0027531597297638655
# accuracy.item() 1
# loss 5.960462772236497e-07
# accuracy.item() 1
# loss 0.03824348375201225
# accuracy.item() 1
# loss 8.344646857949556e-07
# accuracy.item() 1
# loss 0.0037439032457768917
# accuracy.item() 1
# loss 0.002293101279065013
# accuracy.item() 1
# loss 0.025619665160775185
# accuracy.item() 1
# loss 1.1205610462639015e-05
# accuracy.item() 1

# %% [markdown]
# # Test the model

# %%
y_actu=[]
y_pred=[]
#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model.to('cpu')
model.eval()
for every_test_list in test_list:
    label1=every_test_list['label']
    label1=torch.tensor([label1])
    sprectrome=every_test_list['sprectrome']
    text=every_test_list['text']
    input_ids = torch.tensor(tokenizer.encode(text, add_special_tokens=True)).unsqueeze(0)
    with torch.no_grad():
      if(sprectrome.shape[2]>65):
        #sprectrome = sprectrome.to('cuda')
        #label1=label1.to('cuda')
        output = model(input_ids,sprectrome)
        _, preds = torch.max(output, 1)
        y_actu.append(label1.numpy()[0])
        y_pred.append(preds.numpy()[0])

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_actu, y_pred)
# Out:
# array([[106,   0,   1,   2],
#        [  0, 150,   3,   5],
#        [  0,   2, 112,   3],
#        [  3,   2,   5, 139]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_actu,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       109
#            1       0.97      0.95      0.96       158
#            2       0.93      0.96      0.94       117
#            3       0.93      0.93      0.93       149
#
#     accuracy                           0.95       533
#    macro avg       0.95      0.95      0.95       533
# weighted avg       0.95      0.95      0.95       533

# %%
torch.save(model, '/kaggle/working/Combined_model_audio_text.pt')
